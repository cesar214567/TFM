# %% [markdown]
# # Violence Detection using CNN + LSTM neural netowrk

# %% [markdown]
# ## Imports

# %%
#!pip install kagglehub

# %%
# %matplotlib inline
import cv2
import os
import numpy as np
import keras
import matplotlib.pyplot as plt
import kagglehub
import shutil

# import download
from random import shuffle
import tensorflow as tf

import sys
import h5py

current_dir = os.getcwd()
print(current_dir)
sys.path.append(current_dir+'/utils')
from utils.datamanager import download_dataset, label_video_names
from utils.pipeline import getLSTM
# Out:
# c:\Users\Cesar\Desktop\maestria\TFM

# %% [markdown]
# ## Check if gpu enabled

# %%
# Check if TensorFlow can see a GPU
gpus = tf.config.list_physical_devices('GPU')
print("Num GPUs Available:", len(gpus))
print("GPU Details:", gpus)
# Out:
# Num GPUs Available: 1
# GPU Details: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Download dataset

# %%
#current_dir = os.getcwd()

#download_dataset(current_dir)

# %% [markdown]
# ## Load Data
#
# Firstly, we define the directory to place the video dataset

# %%
in_dir = "data"

# %% [markdown]
# Copy some of the data-dimensions for convenience.

# %%
# Frame size  
img_size = 224

img_size_touple = (img_size, img_size)

# Number of channels (RGB)
num_channels = 3

img_size_tiplet = (img_size, img_size,num_channels)

# Flat frame size
img_size_flat = img_size * img_size * num_channels

# Number of classes for classification (Violence-No Violence)
num_classes = 2

frames_per_file = 10
_images_per_file = frames_per_file


# Video extension
video_exts = ".avi"

# %% [markdown]
# In order to load the saved transfer values into RAM memory we are going to use this two functions:

# %%
def process_alldata(file):
    
    joint_transfer=[]
    frames_num=20
    count = 0
    
    with h5py.File(file, 'r') as f:
            
        X_batch = f['data'][:]
        y_batch = f['labels'][:]

    for i in range(int(len(X_batch)/frames_num)):
        inc = count+frames_num
        joint_transfer.append([X_batch[count:inc],y_batch[count]])
        count =inc
        
    data =[]
    target=[]
    
    for i in joint_transfer:
        data.append(i[0])
        target.append(np.array(i[1]))
        
    return data, target

# %% [markdown]
# ##Recurrent Neural Network

# %% [markdown]
# ### Define LSTM architecture

# %% [markdown]
# check utils.pipeline.py

# %% [markdown]
# ## Model training

# %%
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
n_chunks = _images_per_file

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    min_delta=0.005,          # training stops if val_loss improves less than 0.001
    restore_best_weights=True
)

np.random.seed(42)
tf.random.set_seed(42)

def train_model(data, target, input_size, cells, batchs = 16, epochs=200):
    model = getLSTM(cells,input_size,n_chunks)
    X_train, X_val, y_train, y_val = train_test_split(data, target, test_size=0.2, random_state=42)
    history = model.fit(np.array(X_train), np.array(y_train), epochs=epochs,
                        validation_data=(np.array(X_val), np.array(y_val)), 
                        batch_size=batchs, verbose=2, callbacks=[early_stopping])
    return model, history

# %% [markdown]
# ## Test the model and print results

# %% [markdown]
# We are going to test the model with 20 % of the total videos. This videos have not been used to train the network.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Directorios
script_dir = os.getcwd()
training_dir = os.path.join(script_dir, "processedData/training/")
testing_dir = os.path.join(script_dir, "processedData/testing/")
graphs_dir = os.path.join(script_dir, "graphs/")
os.makedirs(graphs_dir, exist_ok=True)

# Rango de LSTM cells
cells_start = 1
cells_end = 10
cells_list = list(range(cells_start, cells_end))  # 1 to 9 cells

for filename in os.listdir(training_dir):
    print(f"Processing CNN Model: {filename}")
    cnn_name = filename.split('.')[0]  # Nombre base para gráficas/CSV

    # Cargar datos
    data, target = process_alldata(os.path.join(training_dir, filename))
    data_test, target_test = process_alldata(os.path.join(testing_dir, filename))

    model_metrics = []   # Métricas por época (para gráficas)
    final_metrics = []   # Métricas finales por configuración (para CSV)

    for cells in cells_list:
        print(f"  → LSTM cells: {cells}")
        model, history = train_model(data, target, data[0].shape[1], cells)

        # Guardar métricas por época
        for epoch, (loss, acc, val_loss, val_acc) in enumerate(zip(
            history.history['loss'],
            history.history['accuracy'],
            history.history['val_loss'],
            history.history['val_accuracy']
        ), start=1):
            model_metrics.append({
                'cnn_model': cnn_name,
                'lstm_cells': cells,
                'epoch': epoch,
                'train_loss': loss,
                'train_accuracy': acc,
                'val_loss': val_loss,
                'val_accuracy': val_acc
            })

        # Evaluar en conjunto de prueba
        test_loss, test_accuracy = model.evaluate(np.array(data_test), np.array(target_test), verbose=0)

        # Guardar métricas finales
        final_metrics.append({
            'Celdas Bi-LSTM': cells,
            'Perdida entrenamiento': round(history.history['loss'][-1], 2),
            'Accuracy entrenamiento': round(history.history['accuracy'][-1], 2),
            'Perdida validacion': round(history.history['val_loss'][-1], 2),
            'Accuracy validacion': round(history.history['val_accuracy'][-1], 2),
            'Perdida prueba': round(test_loss, 2),
            'Accuracy prueba': round(test_accuracy, 2)
        })

    # Crear y guardar métricas finales en CSV
    df_final = pd.DataFrame(final_metrics)
    df_final.to_csv(os.path.join(graphs_dir, f"{cnn_name}_metrics.csv"), index=False)

    # Crear DataFrame con métricas por época
    df_model = pd.DataFrame(model_metrics)

    # === Encontrar la mejor configuración ===
    best_index = df_final['Accuracy prueba'].idxmax()
    best_cells = df_final.loc[best_index, 'Celdas Bi-LSTM']
    best_model_subset = df_model[df_model['lstm_cells'] == best_cells]

    # Insertar punto inicial ficticio para curvas
    first_row = pd.DataFrame({'epoch': [0], 'val_accuracy': [0], 'val_loss': [1]})
    best_model_subset_val_acc = pd.concat([first_row, best_model_subset[['epoch', 'val_accuracy']]], ignore_index=True)
    best_model_subset_val_loss = pd.concat([first_row, best_model_subset[['epoch', 'val_loss']]], ignore_index=True)

    # === Graficar Accuracy ===
    plt.figure(figsize=(10, 6))
    plt.plot(best_model_subset_val_acc['epoch'], best_model_subset_val_acc['val_accuracy'],
             label=f'{best_cells} cells (best)', color='green')
    plt.title(f'Best Validation Accuracy Score Curve - {cnn_name}')
    plt.xlabel('Epoch')
    plt.ylabel('Validation Accuracy')
    plt.ylim(bottom=0)
    plt.grid(True)
    plt.legend()
    plt.savefig(os.path.join(graphs_dir, f"{cnn_name}_best_val_accuracy.png"), dpi=300)
    plt.close()

    # === Graficar Loss ===
    plt.figure(figsize=(10, 6))
    plt.plot(best_model_subset_val_loss['epoch'], best_model_subset_val_loss['val_loss'],
             label=f'{best_cells} cells (best)', color='red')
    plt.title(f'Best Validation Loss Curve - {cnn_name}')
    plt.xlabel('Epoch')
    plt.ylabel('Validation Loss')
    plt.ylim(bottom=0)
    plt.grid(True)
    plt.legend()
    plt.savefig(os.path.join(graphs_dir, f"{cnn_name}_best_val_loss.png"), dpi=300)
    plt.close()
# Out:
# Processing CNN Model: efficientnetb0.h5
#   → LSTM cells: 1
# Epoch 1/200
# 20/20 - 7s - loss: 0.5860 - accuracy: 0.8031 - val_loss: 0.3970 - val_accuracy: 0.8750 - 7s/epoch - 356ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2997 - accuracy: 0.9031 - val_loss: 0.2288 - val_accuracy: 0.9125 - 435ms/epoch - 22ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2024 - accuracy: 0.9406 - val_loss: 0.2688 - val_accuracy: 0.8875 - 404ms/epoch - 20ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1744 - accuracy: 0.9469 - val_loss: 0.1933 - val_accuracy: 0.9250 - 371ms/epoch - 19ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1358 - accuracy: 0.9625 - val_loss: 0.1607 - val_accuracy: 0.9500 - 313ms/epoch - 16ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1085 - accuracy: 0.9656 - val_loss: 0.1650 - val_accuracy: 0.9500 - 316ms/epoch - 16ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0851 - accuracy: 0.9812 - val_loss: 0.1879 - val_accuracy: 0.9375 - 311ms/epoch - 16ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0663 - accuracy: 0.9844 - val_loss: 0.2151 - val_accuracy: 0.9375 - 316ms/epoch - 16ms/step
#   → LSTM cells: 2
# Epoch 1/200
# 20/20 - 7s - loss: 0.5551 - accuracy: 0.7969 - val_loss: 0.3313 - val_accuracy: 0.9000 - 7s/epoch - 336ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2580 - accuracy: 0.9344 - val_loss: 0.2858 - val_accuracy: 0.9125 - 483ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2186 - accuracy: 0.9312 - val_loss: 0.2194 - val_accuracy: 0.9375 - 415ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1792 - accuracy: 0.9500 - val_loss: 0.1227 - val_accuracy: 0.9625 - 354ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1304 - accuracy: 0.9625 - val_loss: 0.1133 - val_accuracy: 0.9625 - 361ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1186 - accuracy: 0.9563 - val_loss: 0.1030 - val_accuracy: 0.9750 - 360ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0822 - accuracy: 0.9781 - val_loss: 0.1184 - val_accuracy: 0.9625 - 347ms/epoch - 17ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0740 - accuracy: 0.9812 - val_loss: 0.1297 - val_accuracy: 0.9750 - 342ms/epoch - 17ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0481 - accuracy: 0.9875 - val_loss: 0.1012 - val_accuracy: 0.9750 - 356ms/epoch - 18ms/step
#   → LSTM cells: 3
# Epoch 1/200
# 20/20 - 6s - loss: 0.5009 - accuracy: 0.8188 - val_loss: 0.3433 - val_accuracy: 0.8875 - 6s/epoch - 298ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2525 - accuracy: 0.9250 - val_loss: 0.1991 - val_accuracy: 0.9250 - 508ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1688 - accuracy: 0.9531 - val_loss: 0.1557 - val_accuracy: 0.9500 - 463ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1359 - accuracy: 0.9625 - val_loss: 0.1040 - val_accuracy: 0.9750 - 369ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1028 - accuracy: 0.9750 - val_loss: 0.2070 - val_accuracy: 0.9375 - 433ms/epoch - 22ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0886 - accuracy: 0.9812 - val_loss: 0.0945 - val_accuracy: 0.9875 - 376ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0878 - accuracy: 0.9719 - val_loss: 0.1243 - val_accuracy: 0.9625 - 362ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0642 - accuracy: 0.9750 - val_loss: 0.1543 - val_accuracy: 0.9625 - 363ms/epoch - 18ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0357 - accuracy: 0.9875 - val_loss: 0.1602 - val_accuracy: 0.9625 - 357ms/epoch - 18ms/step
#   → LSTM cells: 4
# Epoch 1/200
# 20/20 - 6s - loss: 0.6045 - accuracy: 0.6969 - val_loss: 0.3954 - val_accuracy: 0.8875 - 6s/epoch - 298ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2939 - accuracy: 0.9000 - val_loss: 0.1907 - val_accuracy: 0.9250 - 453ms/epoch - 23ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2115 - accuracy: 0.9469 - val_loss: 0.1964 - val_accuracy: 0.9375 - 359ms/epoch - 18ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1655 - accuracy: 0.9438 - val_loss: 0.1654 - val_accuracy: 0.9375 - 367ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1226 - accuracy: 0.9594 - val_loss: 0.1151 - val_accuracy: 0.9625 - 357ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0786 - accuracy: 0.9688 - val_loss: 0.1212 - val_accuracy: 0.9625 - 349ms/epoch - 17ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0381 - accuracy: 0.9875 - val_loss: 0.1347 - val_accuracy: 0.9500 - 351ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0216 - accuracy: 0.9906 - val_loss: 0.1409 - val_accuracy: 0.9500 - 362ms/epoch - 18ms/step
#   → LSTM cells: 5
# Epoch 1/200
# 20/20 - 6s - loss: 0.4551 - accuracy: 0.8375 - val_loss: 0.2390 - val_accuracy: 0.9125 - 6s/epoch - 309ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2349 - accuracy: 0.9281 - val_loss: 0.1953 - val_accuracy: 0.9500 - 515ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1713 - accuracy: 0.9438 - val_loss: 0.1621 - val_accuracy: 0.9625 - 459ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1428 - accuracy: 0.9594 - val_loss: 0.1936 - val_accuracy: 0.9500 - 369ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1082 - accuracy: 0.9656 - val_loss: 0.1629 - val_accuracy: 0.9625 - 363ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0815 - accuracy: 0.9719 - val_loss: 0.1480 - val_accuracy: 0.9625 - 360ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0502 - accuracy: 0.9844 - val_loss: 0.1489 - val_accuracy: 0.9625 - 379ms/epoch - 19ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0284 - accuracy: 0.9906 - val_loss: 0.1754 - val_accuracy: 0.9625 - 359ms/epoch - 18ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0163 - accuracy: 0.9937 - val_loss: 0.1633 - val_accuracy: 0.9625 - 369ms/epoch - 18ms/step
#   → LSTM cells: 6
# Epoch 1/200
# 20/20 - 6s - loss: 0.4711 - accuracy: 0.8531 - val_loss: 0.2618 - val_accuracy: 0.9375 - 6s/epoch - 308ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2697 - accuracy: 0.9125 - val_loss: 0.1621 - val_accuracy: 0.9625 - 483ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2091 - accuracy: 0.9281 - val_loss: 0.1303 - val_accuracy: 0.9500 - 373ms/epoch - 19ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1509 - accuracy: 0.9563 - val_loss: 0.1388 - val_accuracy: 0.9750 - 365ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1023 - accuracy: 0.9781 - val_loss: 0.1246 - val_accuracy: 0.9625 - 378ms/epoch - 19ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0709 - accuracy: 0.9812 - val_loss: 0.1254 - val_accuracy: 0.9625 - 354ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0428 - accuracy: 0.9844 - val_loss: 0.1459 - val_accuracy: 0.9500 - 360ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0256 - accuracy: 0.9937 - val_loss: 0.1189 - val_accuracy: 0.9750 - 375ms/epoch - 19ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.1239 - val_accuracy: 0.9625 - 359ms/epoch - 18ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0053 - accuracy: 0.9969 - val_loss: 0.1288 - val_accuracy: 0.9750 - 356ms/epoch - 18ms/step
# Epoch 11/200
# 20/20 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.9750 - 382ms/epoch - 19ms/step
#   → LSTM cells: 7
# Epoch 1/200
# 20/20 - 6s - loss: 0.4504 - accuracy: 0.8313 - val_loss: 0.2095 - val_accuracy: 0.9250 - 6s/epoch - 314ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2511 - accuracy: 0.9250 - val_loss: 0.1512 - val_accuracy: 0.9625 - 436ms/epoch - 22ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1768 - accuracy: 0.9469 - val_loss: 0.1105 - val_accuracy: 0.9875 - 365ms/epoch - 18ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1236 - accuracy: 0.9656 - val_loss: 0.1354 - val_accuracy: 0.9625 - 361ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0723 - accuracy: 0.9844 - val_loss: 0.1501 - val_accuracy: 0.9625 - 360ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0521 - accuracy: 0.9875 - val_loss: 0.1898 - val_accuracy: 0.9625 - 371ms/epoch - 19ms/step
#   → LSTM cells: 8
# Epoch 1/200
# 20/20 - 6s - loss: 0.4618 - accuracy: 0.8219 - val_loss: 0.2193 - val_accuracy: 0.9375 - 6s/epoch - 309ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2259 - accuracy: 0.9281 - val_loss: 0.1988 - val_accuracy: 0.9250 - 499ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1559 - accuracy: 0.9563 - val_loss: 0.1230 - val_accuracy: 0.9750 - 463ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1019 - accuracy: 0.9719 - val_loss: 0.1226 - val_accuracy: 0.9750 - 363ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0738 - accuracy: 0.9812 - val_loss: 0.1169 - val_accuracy: 0.9625 - 364ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0479 - accuracy: 0.9906 - val_loss: 0.1405 - val_accuracy: 0.9750 - 359ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0383 - accuracy: 0.9906 - val_loss: 0.1417 - val_accuracy: 0.9750 - 359ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0261 - accuracy: 0.9906 - val_loss: 0.1421 - val_accuracy: 0.9750 - 364ms/epoch - 18ms/step
#   → LSTM cells: 9
# Epoch 1/200
# 20/20 - 6s - loss: 0.4524 - accuracy: 0.7969 - val_loss: 0.1752 - val_accuracy: 0.9500 - 6s/epoch - 297ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2021 - accuracy: 0.9344 - val_loss: 0.1701 - val_accuracy: 0.9500 - 509ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1346 - accuracy: 0.9500 - val_loss: 0.0984 - val_accuracy: 0.9750 - 374ms/epoch - 19ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.0826 - accuracy: 0.9750 - val_loss: 0.1265 - val_accuracy: 0.9750 - 358ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0491 - accuracy: 0.9906 - val_loss: 0.1289 - val_accuracy: 0.9750 - 368ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0187 - accuracy: 0.9906 - val_loss: 0.1404 - val_accuracy: 0.9750 - 382ms/epoch - 19ms/step
# Processing CNN Model: efficientnetv2-s.h5
#   → LSTM cells: 1
# Epoch 1/200
# 20/20 - 6s - loss: 0.6536 - accuracy: 0.6750 - val_loss: 0.5056 - val_accuracy: 0.8625 - 6s/epoch - 319ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.3772 - accuracy: 0.9000 - val_loss: 0.2692 - val_accuracy: 0.9000 - 428ms/epoch - 21ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2400 - accuracy: 0.9125 - val_loss: 0.2854 - val_accuracy: 0.9000 - 398ms/epoch - 20ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.2029 - accuracy: 0.9344 - val_loss: 0.2001 - val_accuracy: 0.9375 - 364ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1480 - accuracy: 0.9563 - val_loss: 0.1901 - val_accuracy: 0.9375 - 319ms/epoch - 16ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1170 - accuracy: 0.9625 - val_loss: 0.1752 - val_accuracy: 0.9375 - 314ms/epoch - 16ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0996 - accuracy: 0.9781 - val_loss: 0.1973 - val_accuracy: 0.9375 - 307ms/epoch - 15ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0767 - accuracy: 0.9781 - val_loss: 0.1776 - val_accuracy: 0.9375 - 302ms/epoch - 15ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0710 - accuracy: 0.9875 - val_loss: 0.2252 - val_accuracy: 0.9375 - 318ms/epoch - 16ms/step
#   → LSTM cells: 2
# Epoch 1/200
# 20/20 - 6s - loss: 0.5829 - accuracy: 0.8000 - val_loss: 0.3539 - val_accuracy: 0.9000 - 6s/epoch - 294ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2835 - accuracy: 0.9125 - val_loss: 0.2570 - val_accuracy: 0.9125 - 480ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2252 - accuracy: 0.9344 - val_loss: 0.2462 - val_accuracy: 0.9250 - 473ms/epoch - 24ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1871 - accuracy: 0.9406 - val_loss: 0.2118 - val_accuracy: 0.9500 - 392ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1645 - accuracy: 0.9563 - val_loss: 0.2031 - val_accuracy: 0.9375 - 363ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1448 - accuracy: 0.9594 - val_loss: 0.2026 - val_accuracy: 0.9375 - 348ms/epoch - 17ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1095 - accuracy: 0.9656 - val_loss: 0.2041 - val_accuracy: 0.9500 - 355ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0839 - accuracy: 0.9812 - val_loss: 0.2168 - val_accuracy: 0.9375 - 361ms/epoch - 18ms/step
#   → LSTM cells: 3
# Epoch 1/200
# 20/20 - 6s - loss: 0.6149 - accuracy: 0.7656 - val_loss: 0.3883 - val_accuracy: 0.9250 - 6s/epoch - 301ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2917 - accuracy: 0.9156 - val_loss: 0.2290 - val_accuracy: 0.9250 - 496ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2246 - accuracy: 0.9281 - val_loss: 0.2031 - val_accuracy: 0.9375 - 460ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1710 - accuracy: 0.9406 - val_loss: 0.1808 - val_accuracy: 0.9375 - 373ms/epoch - 19ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1261 - accuracy: 0.9625 - val_loss: 0.1923 - val_accuracy: 0.9375 - 364ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1065 - accuracy: 0.9688 - val_loss: 0.1612 - val_accuracy: 0.9375 - 367ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0971 - accuracy: 0.9688 - val_loss: 0.2213 - val_accuracy: 0.9375 - 360ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0863 - accuracy: 0.9781 - val_loss: 0.2327 - val_accuracy: 0.9500 - 357ms/epoch - 18ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0685 - accuracy: 0.9844 - val_loss: 0.2586 - val_accuracy: 0.9375 - 457ms/epoch - 23ms/step
#   → LSTM cells: 4
# Epoch 1/200
# 20/20 - 6s - loss: 0.5471 - accuracy: 0.7937 - val_loss: 0.3217 - val_accuracy: 0.9125 - 6s/epoch - 311ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2786 - accuracy: 0.9125 - val_loss: 0.2373 - val_accuracy: 0.9125 - 501ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2159 - accuracy: 0.9406 - val_loss: 0.2074 - val_accuracy: 0.9250 - 423ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1726 - accuracy: 0.9500 - val_loss: 0.1886 - val_accuracy: 0.9500 - 363ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1502 - accuracy: 0.9500 - val_loss: 0.1954 - val_accuracy: 0.9375 - 356ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1247 - accuracy: 0.9563 - val_loss: 0.1793 - val_accuracy: 0.9375 - 366ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0821 - accuracy: 0.9750 - val_loss: 0.1738 - val_accuracy: 0.9500 - 360ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0601 - accuracy: 0.9844 - val_loss: 0.2034 - val_accuracy: 0.9375 - 348ms/epoch - 17ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0467 - accuracy: 0.9875 - val_loss: 0.1970 - val_accuracy: 0.9375 - 354ms/epoch - 18ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0452 - accuracy: 0.9875 - val_loss: 0.4186 - val_accuracy: 0.8875 - 363ms/epoch - 18ms/step
#   → LSTM cells: 5
# Epoch 1/200
# 20/20 - 6s - loss: 0.5265 - accuracy: 0.7812 - val_loss: 0.2834 - val_accuracy: 0.9125 - 6s/epoch - 293ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2577 - accuracy: 0.9125 - val_loss: 0.2013 - val_accuracy: 0.9250 - 505ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1827 - accuracy: 0.9469 - val_loss: 0.2110 - val_accuracy: 0.9375 - 420ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1302 - accuracy: 0.9625 - val_loss: 0.1630 - val_accuracy: 0.9375 - 367ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1016 - accuracy: 0.9656 - val_loss: 0.1838 - val_accuracy: 0.9375 - 363ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0955 - accuracy: 0.9750 - val_loss: 0.1640 - val_accuracy: 0.9500 - 360ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0663 - accuracy: 0.9781 - val_loss: 0.1472 - val_accuracy: 0.9500 - 362ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0340 - accuracy: 0.9937 - val_loss: 0.1943 - val_accuracy: 0.9375 - 360ms/epoch - 18ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0210 - accuracy: 0.9969 - val_loss: 0.2274 - val_accuracy: 0.9375 - 354ms/epoch - 18ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0192 - accuracy: 0.9969 - val_loss: 0.2323 - val_accuracy: 0.9375 - 362ms/epoch - 18ms/step
#   → LSTM cells: 6
# Epoch 1/200
# 20/20 - 6s - loss: 0.5063 - accuracy: 0.7875 - val_loss: 0.3462 - val_accuracy: 0.8500 - 6s/epoch - 320ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2722 - accuracy: 0.8938 - val_loss: 0.2195 - val_accuracy: 0.9250 - 517ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1831 - accuracy: 0.9375 - val_loss: 0.2344 - val_accuracy: 0.9375 - 420ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1369 - accuracy: 0.9563 - val_loss: 0.2202 - val_accuracy: 0.9250 - 372ms/epoch - 19ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1208 - accuracy: 0.9750 - val_loss: 0.2022 - val_accuracy: 0.9125 - 363ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0847 - accuracy: 0.9750 - val_loss: 0.1804 - val_accuracy: 0.9625 - 369ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0540 - accuracy: 0.9844 - val_loss: 0.3132 - val_accuracy: 0.9375 - 355ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0626 - accuracy: 0.9844 - val_loss: 0.2893 - val_accuracy: 0.9250 - 355ms/epoch - 18ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0793 - accuracy: 0.9656 - val_loss: 0.3439 - val_accuracy: 0.9375 - 363ms/epoch - 18ms/step
#   → LSTM cells: 7
# Epoch 1/200
# 20/20 - 7s - loss: 0.5602 - accuracy: 0.7156 - val_loss: 0.2894 - val_accuracy: 0.9000 - 7s/epoch - 328ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2662 - accuracy: 0.9094 - val_loss: 0.2056 - val_accuracy: 0.9250 - 565ms/epoch - 28ms/step
# Epoch 3/200
# 20/20 - 1s - loss: 0.1757 - accuracy: 0.9406 - val_loss: 0.2862 - val_accuracy: 0.9000 - 513ms/epoch - 26ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1608 - accuracy: 0.9500 - val_loss: 0.1532 - val_accuracy: 0.9375 - 444ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1159 - accuracy: 0.9594 - val_loss: 0.1675 - val_accuracy: 0.9375 - 366ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0888 - accuracy: 0.9688 - val_loss: 0.1478 - val_accuracy: 0.9625 - 377ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0722 - accuracy: 0.9781 - val_loss: 0.1670 - val_accuracy: 0.9750 - 362ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0521 - accuracy: 0.9812 - val_loss: 0.1763 - val_accuracy: 0.9625 - 358ms/epoch - 18ms/step
# Epoch 9/200
# 20/20 - 1s - loss: 0.0300 - accuracy: 0.9875 - val_loss: 0.1802 - val_accuracy: 0.9625 - 514ms/epoch - 26ms/step
#   → LSTM cells: 8
# Epoch 1/200
# 20/20 - 9s - loss: 0.4699 - accuracy: 0.8375 - val_loss: 0.2097 - val_accuracy: 0.9125 - 9s/epoch - 426ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2354 - accuracy: 0.9281 - val_loss: 0.1791 - val_accuracy: 0.9500 - 971ms/epoch - 49ms/step
# Epoch 3/200
# 20/20 - 1s - loss: 0.1757 - accuracy: 0.9375 - val_loss: 0.1524 - val_accuracy: 0.9375 - 875ms/epoch - 44ms/step
# Epoch 4/200
# 20/20 - 1s - loss: 0.1420 - accuracy: 0.9625 - val_loss: 0.1744 - val_accuracy: 0.9000 - 738ms/epoch - 37ms/step
# Epoch 5/200
# 20/20 - 1s - loss: 0.1073 - accuracy: 0.9750 - val_loss: 0.1795 - val_accuracy: 0.9250 - 572ms/epoch - 29ms/step
# Epoch 6/200
# 20/20 - 1s - loss: 0.1004 - accuracy: 0.9625 - val_loss: 0.1811 - val_accuracy: 0.9375 - 528ms/epoch - 26ms/step
#   → LSTM cells: 9
# Epoch 1/200
# 20/20 - 10s - loss: 0.5176 - accuracy: 0.8031 - val_loss: 0.2638 - val_accuracy: 0.9000 - 10s/epoch - 518ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2556 - accuracy: 0.9187 - val_loss: 0.2005 - val_accuracy: 0.9250 - 548ms/epoch - 27ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1765 - accuracy: 0.9469 - val_loss: 0.1806 - val_accuracy: 0.9125 - 451ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1401 - accuracy: 0.9688 - val_loss: 0.1516 - val_accuracy: 0.9375 - 379ms/epoch - 19ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1095 - accuracy: 0.9688 - val_loss: 0.1443 - val_accuracy: 0.9500 - 370ms/epoch - 19ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0927 - accuracy: 0.9719 - val_loss: 0.1413 - val_accuracy: 0.9625 - 366ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0593 - accuracy: 0.9812 - val_loss: 0.1458 - val_accuracy: 0.9625 - 360ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0388 - accuracy: 0.9906 - val_loss: 0.1599 - val_accuracy: 0.9625 - 375ms/epoch - 19ms/step
# Processing CNN Model: MobilenetV3large.h5
#   → LSTM cells: 1
# Epoch 1/200
# 20/20 - 6s - loss: 0.6808 - accuracy: 0.6281 - val_loss: 0.6270 - val_accuracy: 0.8875 - 6s/epoch - 309ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.4885 - accuracy: 0.9094 - val_loss: 0.3322 - val_accuracy: 0.9125 - 403ms/epoch - 20ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.3275 - accuracy: 0.8938 - val_loss: 0.3093 - val_accuracy: 0.9125 - 397ms/epoch - 20ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.2489 - accuracy: 0.9344 - val_loss: 0.2610 - val_accuracy: 0.9250 - 386ms/epoch - 19ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1942 - accuracy: 0.9438 - val_loss: 0.2049 - val_accuracy: 0.9375 - 429ms/epoch - 21ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.2466 - accuracy: 0.9250 - val_loss: 0.3683 - val_accuracy: 0.8625 - 481ms/epoch - 24ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.2452 - accuracy: 0.9125 - val_loss: 0.2243 - val_accuracy: 0.9000 - 393ms/epoch - 20ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.1834 - accuracy: 0.9438 - val_loss: 0.2372 - val_accuracy: 0.9250 - 371ms/epoch - 19ms/step
#   → LSTM cells: 2
# Epoch 1/200
# 20/20 - 7s - loss: 0.5421 - accuracy: 0.7656 - val_loss: 0.4524 - val_accuracy: 0.7625 - 7s/epoch - 341ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2928 - accuracy: 0.8844 - val_loss: 0.3539 - val_accuracy: 0.8500 - 446ms/epoch - 22ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2165 - accuracy: 0.9250 - val_loss: 0.2607 - val_accuracy: 0.9250 - 433ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1761 - accuracy: 0.9438 - val_loss: 0.2494 - val_accuracy: 0.9125 - 432ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1258 - accuracy: 0.9594 - val_loss: 0.2200 - val_accuracy: 0.9500 - 430ms/epoch - 21ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1125 - accuracy: 0.9719 - val_loss: 0.1814 - val_accuracy: 0.9500 - 361ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0699 - accuracy: 0.9812 - val_loss: 0.2025 - val_accuracy: 0.9500 - 339ms/epoch - 17ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0512 - accuracy: 0.9844 - val_loss: 0.2459 - val_accuracy: 0.9375 - 397ms/epoch - 20ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0370 - accuracy: 0.9937 - val_loss: 0.1963 - val_accuracy: 0.9375 - 346ms/epoch - 17ms/step
#   → LSTM cells: 3
# Epoch 1/200
# 20/20 - 6s - loss: 0.5382 - accuracy: 0.7750 - val_loss: 0.3573 - val_accuracy: 0.8750 - 6s/epoch - 317ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.3237 - accuracy: 0.8875 - val_loss: 0.3376 - val_accuracy: 0.9125 - 475ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2262 - accuracy: 0.9219 - val_loss: 0.2452 - val_accuracy: 0.9250 - 448ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1855 - accuracy: 0.9344 - val_loss: 0.1979 - val_accuracy: 0.9375 - 392ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1370 - accuracy: 0.9531 - val_loss: 0.2034 - val_accuracy: 0.9000 - 339ms/epoch - 17ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0952 - accuracy: 0.9750 - val_loss: 0.2407 - val_accuracy: 0.9125 - 334ms/epoch - 17ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0757 - accuracy: 0.9812 - val_loss: 0.1557 - val_accuracy: 0.9500 - 346ms/epoch - 17ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0458 - accuracy: 0.9875 - val_loss: 0.1665 - val_accuracy: 0.9500 - 349ms/epoch - 17ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0328 - accuracy: 0.9906 - val_loss: 0.1752 - val_accuracy: 0.9500 - 367ms/epoch - 18ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0231 - accuracy: 0.9937 - val_loss: 0.2367 - val_accuracy: 0.9500 - 356ms/epoch - 18ms/step
#   → LSTM cells: 4
# Epoch 1/200
# 20/20 - 6s - loss: 0.5845 - accuracy: 0.7188 - val_loss: 0.3482 - val_accuracy: 0.9250 - 6s/epoch - 319ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.3303 - accuracy: 0.8687 - val_loss: 0.1906 - val_accuracy: 0.9500 - 472ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2444 - accuracy: 0.9156 - val_loss: 0.2031 - val_accuracy: 0.9125 - 444ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.2073 - accuracy: 0.9344 - val_loss: 0.1560 - val_accuracy: 0.9500 - 415ms/epoch - 21ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1534 - accuracy: 0.9594 - val_loss: 0.1684 - val_accuracy: 0.9500 - 338ms/epoch - 17ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1346 - accuracy: 0.9656 - val_loss: 0.1454 - val_accuracy: 0.9500 - 345ms/epoch - 17ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1155 - accuracy: 0.9688 - val_loss: 0.1310 - val_accuracy: 0.9625 - 342ms/epoch - 17ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0944 - accuracy: 0.9781 - val_loss: 0.1321 - val_accuracy: 0.9625 - 344ms/epoch - 17ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0812 - accuracy: 0.9781 - val_loss: 0.1414 - val_accuracy: 0.9625 - 360ms/epoch - 18ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0631 - accuracy: 0.9812 - val_loss: 0.1532 - val_accuracy: 0.9625 - 366ms/epoch - 18ms/step
#   → LSTM cells: 5
# Epoch 1/200
# 20/20 - 8s - loss: 0.5207 - accuracy: 0.7781 - val_loss: 0.2335 - val_accuracy: 0.9125 - 8s/epoch - 407ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2373 - accuracy: 0.9250 - val_loss: 0.1799 - val_accuracy: 0.9500 - 557ms/epoch - 28ms/step
# Epoch 3/200
# 20/20 - 1s - loss: 0.1629 - accuracy: 0.9375 - val_loss: 0.1749 - val_accuracy: 0.9375 - 529ms/epoch - 26ms/step
# Epoch 4/200
# 20/20 - 1s - loss: 0.1673 - accuracy: 0.9375 - val_loss: 0.1314 - val_accuracy: 0.9625 - 509ms/epoch - 25ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0949 - accuracy: 0.9750 - val_loss: 0.1598 - val_accuracy: 0.9625 - 465ms/epoch - 23ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0715 - accuracy: 0.9812 - val_loss: 0.1440 - val_accuracy: 0.9625 - 452ms/epoch - 23ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0521 - accuracy: 0.9875 - val_loss: 0.1849 - val_accuracy: 0.9500 - 389ms/epoch - 19ms/step
#   → LSTM cells: 6
# Epoch 1/200
# 20/20 - 7s - loss: 0.5782 - accuracy: 0.7188 - val_loss: 0.3732 - val_accuracy: 0.9000 - 7s/epoch - 335ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2687 - accuracy: 0.9281 - val_loss: 0.2407 - val_accuracy: 0.8750 - 497ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1561 - accuracy: 0.9594 - val_loss: 0.1688 - val_accuracy: 0.9500 - 467ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1367 - accuracy: 0.9531 - val_loss: 0.1593 - val_accuracy: 0.9500 - 433ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0947 - accuracy: 0.9750 - val_loss: 0.2073 - val_accuracy: 0.9375 - 353ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0742 - accuracy: 0.9750 - val_loss: 0.2349 - val_accuracy: 0.9125 - 347ms/epoch - 17ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0724 - accuracy: 0.9812 - val_loss: 0.1798 - val_accuracy: 0.9375 - 359ms/epoch - 18ms/step
#   → LSTM cells: 7
# Epoch 1/200
# 20/20 - 7s - loss: 0.5147 - accuracy: 0.7937 - val_loss: 0.2670 - val_accuracy: 0.9000 - 7s/epoch - 336ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2289 - accuracy: 0.9312 - val_loss: 0.2420 - val_accuracy: 0.9250 - 488ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1560 - accuracy: 0.9563 - val_loss: 0.1951 - val_accuracy: 0.9500 - 460ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1147 - accuracy: 0.9656 - val_loss: 0.1999 - val_accuracy: 0.9500 - 352ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0770 - accuracy: 0.9781 - val_loss: 0.1930 - val_accuracy: 0.9500 - 351ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0504 - accuracy: 0.9781 - val_loss: 0.1876 - val_accuracy: 0.9375 - 349ms/epoch - 17ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0551 - accuracy: 0.9781 - val_loss: 0.2159 - val_accuracy: 0.9375 - 348ms/epoch - 17ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0701 - accuracy: 0.9750 - val_loss: 0.1968 - val_accuracy: 0.9500 - 348ms/epoch - 17ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0285 - accuracy: 0.9875 - val_loss: 0.1937 - val_accuracy: 0.9375 - 359ms/epoch - 18ms/step
#   → LSTM cells: 8
# Epoch 1/200
# 20/20 - 6s - loss: 0.5110 - accuracy: 0.8250 - val_loss: 0.2669 - val_accuracy: 0.9000 - 6s/epoch - 314ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2229 - accuracy: 0.9250 - val_loss: 0.2179 - val_accuracy: 0.9125 - 488ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1379 - accuracy: 0.9531 - val_loss: 0.2172 - val_accuracy: 0.9375 - 457ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.0924 - accuracy: 0.9688 - val_loss: 0.2699 - val_accuracy: 0.9125 - 357ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0632 - accuracy: 0.9844 - val_loss: 0.2269 - val_accuracy: 0.9375 - 360ms/epoch - 18ms/step
#   → LSTM cells: 9
# Epoch 1/200
# 20/20 - 6s - loss: 0.4613 - accuracy: 0.8094 - val_loss: 0.2780 - val_accuracy: 0.9000 - 6s/epoch - 321ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2484 - accuracy: 0.9219 - val_loss: 0.2454 - val_accuracy: 0.9000 - 482ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1746 - accuracy: 0.9406 - val_loss: 0.2117 - val_accuracy: 0.9375 - 411ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1356 - accuracy: 0.9594 - val_loss: 0.2088 - val_accuracy: 0.9250 - 347ms/epoch - 17ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1144 - accuracy: 0.9656 - val_loss: 0.2667 - val_accuracy: 0.9250 - 347ms/epoch - 17ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0882 - accuracy: 0.9781 - val_loss: 0.1759 - val_accuracy: 0.9375 - 358ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0527 - accuracy: 0.9781 - val_loss: 0.1631 - val_accuracy: 0.9500 - 348ms/epoch - 17ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0543 - accuracy: 0.9812 - val_loss: 0.1624 - val_accuracy: 0.9375 - 354ms/epoch - 18ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0748 - accuracy: 0.9719 - val_loss: 0.2487 - val_accuracy: 0.9375 - 349ms/epoch - 17ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0554 - accuracy: 0.9750 - val_loss: 0.1924 - val_accuracy: 0.9500 - 359ms/epoch - 18ms/step
# Processing CNN Model: resnet50.h5
#   → LSTM cells: 1
# Epoch 1/200
# 20/20 - 7s - loss: 0.6374 - accuracy: 0.6812 - val_loss: 0.6014 - val_accuracy: 0.7125 - 7s/epoch - 338ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.4837 - accuracy: 0.8188 - val_loss: 0.3351 - val_accuracy: 0.8875 - 499ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.3832 - accuracy: 0.8438 - val_loss: 0.3020 - val_accuracy: 0.9375 - 434ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.2898 - accuracy: 0.8906 - val_loss: 0.2146 - val_accuracy: 0.9375 - 361ms/epoch - 18ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.2254 - accuracy: 0.9281 - val_loss: 0.3142 - val_accuracy: 0.9125 - 356ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.2484 - accuracy: 0.9219 - val_loss: 0.1905 - val_accuracy: 0.9375 - 366ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.2056 - accuracy: 0.9406 - val_loss: 0.2012 - val_accuracy: 0.9250 - 349ms/epoch - 17ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.1916 - accuracy: 0.9406 - val_loss: 0.2050 - val_accuracy: 0.9375 - 351ms/epoch - 18ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.1360 - accuracy: 0.9625 - val_loss: 0.1793 - val_accuracy: 0.9375 - 352ms/epoch - 18ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.1175 - accuracy: 0.9719 - val_loss: 0.1751 - val_accuracy: 0.9500 - 349ms/epoch - 17ms/step
# Epoch 11/200
# 20/20 - 0s - loss: 0.0961 - accuracy: 0.9750 - val_loss: 0.1427 - val_accuracy: 0.9625 - 347ms/epoch - 17ms/step
# Epoch 12/200
# 20/20 - 0s - loss: 0.0823 - accuracy: 0.9781 - val_loss: 0.1685 - val_accuracy: 0.9625 - 346ms/epoch - 17ms/step
# Epoch 13/200
# 20/20 - 0s - loss: 0.1036 - accuracy: 0.9688 - val_loss: 0.1343 - val_accuracy: 0.9625 - 351ms/epoch - 18ms/step
# Epoch 14/200
# 20/20 - 0s - loss: 0.0869 - accuracy: 0.9781 - val_loss: 0.1624 - val_accuracy: 0.9625 - 349ms/epoch - 17ms/step
# Epoch 15/200
# 20/20 - 0s - loss: 0.1159 - accuracy: 0.9656 - val_loss: 0.3476 - val_accuracy: 0.8625 - 350ms/epoch - 17ms/step
# Epoch 16/200
# 20/20 - 0s - loss: 0.1088 - accuracy: 0.9688 - val_loss: 0.1369 - val_accuracy: 0.9750 - 367ms/epoch - 18ms/step
#   → LSTM cells: 2
# Epoch 1/200
# 20/20 - 6s - loss: 0.6206 - accuracy: 0.6812 - val_loss: 0.4310 - val_accuracy: 0.9000 - 6s/epoch - 318ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.3454 - accuracy: 0.8938 - val_loss: 0.2561 - val_accuracy: 0.9125 - 483ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2368 - accuracy: 0.9219 - val_loss: 0.1725 - val_accuracy: 0.9500 - 415ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1904 - accuracy: 0.9438 - val_loss: 0.2074 - val_accuracy: 0.9500 - 405ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.2595 - accuracy: 0.9187 - val_loss: 0.1849 - val_accuracy: 0.9375 - 422ms/epoch - 21ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1978 - accuracy: 0.9375 - val_loss: 0.1689 - val_accuracy: 0.9125 - 403ms/epoch - 20ms/step
#   → LSTM cells: 3
# Epoch 1/200
# 20/20 - 7s - loss: 0.5333 - accuracy: 0.8469 - val_loss: 0.2991 - val_accuracy: 0.9250 - 7s/epoch - 348ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.3045 - accuracy: 0.9094 - val_loss: 0.1925 - val_accuracy: 0.9500 - 541ms/epoch - 27ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2344 - accuracy: 0.9250 - val_loss: 0.1828 - val_accuracy: 0.9500 - 423ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1672 - accuracy: 0.9500 - val_loss: 0.1772 - val_accuracy: 0.9500 - 419ms/epoch - 21ms/step
# Epoch 5/200
# 20/20 - 1s - loss: 0.1225 - accuracy: 0.9656 - val_loss: 0.1998 - val_accuracy: 0.9375 - 518ms/epoch - 26ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1024 - accuracy: 0.9719 - val_loss: 0.2229 - val_accuracy: 0.9500 - 409ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0767 - accuracy: 0.9719 - val_loss: 0.2079 - val_accuracy: 0.9250 - 418ms/epoch - 21ms/step
#   → LSTM cells: 4
# Epoch 1/200
# 20/20 - 6s - loss: 0.6044 - accuracy: 0.7156 - val_loss: 0.4055 - val_accuracy: 0.9500 - 6s/epoch - 318ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.3157 - accuracy: 0.8969 - val_loss: 0.1791 - val_accuracy: 0.9625 - 492ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2115 - accuracy: 0.9375 - val_loss: 0.1818 - val_accuracy: 0.9375 - 398ms/epoch - 20ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1892 - accuracy: 0.9344 - val_loss: 0.1406 - val_accuracy: 0.9500 - 420ms/epoch - 21ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1604 - accuracy: 0.9531 - val_loss: 0.1467 - val_accuracy: 0.9625 - 399ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1689 - accuracy: 0.9469 - val_loss: 0.1565 - val_accuracy: 0.9375 - 405ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1486 - accuracy: 0.9625 - val_loss: 0.1694 - val_accuracy: 0.9500 - 411ms/epoch - 21ms/step
#   → LSTM cells: 5
# Epoch 1/200
# 20/20 - 6s - loss: 0.5285 - accuracy: 0.7781 - val_loss: 0.2867 - val_accuracy: 0.9375 - 6s/epoch - 319ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2888 - accuracy: 0.8938 - val_loss: 0.2007 - val_accuracy: 0.9250 - 521ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2034 - accuracy: 0.9250 - val_loss: 0.1760 - val_accuracy: 0.9375 - 419ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1553 - accuracy: 0.9563 - val_loss: 0.1440 - val_accuracy: 0.9625 - 429ms/epoch - 21ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1239 - accuracy: 0.9688 - val_loss: 0.1699 - val_accuracy: 0.9500 - 414ms/epoch - 21ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0949 - accuracy: 0.9781 - val_loss: 0.1516 - val_accuracy: 0.9625 - 408ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0537 - accuracy: 0.9844 - val_loss: 0.1632 - val_accuracy: 0.9750 - 414ms/epoch - 21ms/step
#   → LSTM cells: 6
# Epoch 1/200
# 20/20 - 7s - loss: 0.4734 - accuracy: 0.7937 - val_loss: 0.2909 - val_accuracy: 0.8875 - 7s/epoch - 337ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2852 - accuracy: 0.8969 - val_loss: 0.2007 - val_accuracy: 0.9250 - 496ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2315 - accuracy: 0.9219 - val_loss: 0.1624 - val_accuracy: 0.9375 - 418ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.2079 - accuracy: 0.9406 - val_loss: 0.1625 - val_accuracy: 0.9500 - 409ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1764 - accuracy: 0.9500 - val_loss: 0.1694 - val_accuracy: 0.9250 - 398ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1512 - accuracy: 0.9563 - val_loss: 0.1893 - val_accuracy: 0.9375 - 402ms/epoch - 20ms/step
#   → LSTM cells: 7
# Epoch 1/200
# 20/20 - 6s - loss: 0.5628 - accuracy: 0.7344 - val_loss: 0.3319 - val_accuracy: 0.9375 - 6s/epoch - 320ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2474 - accuracy: 0.9125 - val_loss: 0.2100 - val_accuracy: 0.9375 - 466ms/epoch - 23ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1757 - accuracy: 0.9438 - val_loss: 0.1601 - val_accuracy: 0.9500 - 424ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1402 - accuracy: 0.9625 - val_loss: 0.1895 - val_accuracy: 0.9500 - 404ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0915 - accuracy: 0.9750 - val_loss: 0.1500 - val_accuracy: 0.9625 - 398ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0718 - accuracy: 0.9781 - val_loss: 0.1515 - val_accuracy: 0.9500 - 396ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0529 - accuracy: 0.9844 - val_loss: 0.1914 - val_accuracy: 0.9625 - 381ms/epoch - 19ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0329 - accuracy: 0.9875 - val_loss: 0.1569 - val_accuracy: 0.9625 - 398ms/epoch - 20ms/step
#   → LSTM cells: 8
# Epoch 1/200
# 20/20 - 7s - loss: 0.5113 - accuracy: 0.8000 - val_loss: 0.3072 - val_accuracy: 0.9125 - 7s/epoch - 346ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2545 - accuracy: 0.9094 - val_loss: 0.1975 - val_accuracy: 0.9375 - 556ms/epoch - 28ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1976 - accuracy: 0.9344 - val_loss: 0.1582 - val_accuracy: 0.9375 - 482ms/epoch - 24ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1369 - accuracy: 0.9563 - val_loss: 0.1590 - val_accuracy: 0.9750 - 450ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0970 - accuracy: 0.9781 - val_loss: 0.1582 - val_accuracy: 0.9625 - 439ms/epoch - 22ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0763 - accuracy: 0.9812 - val_loss: 0.2301 - val_accuracy: 0.9250 - 469ms/epoch - 23ms/step
#   → LSTM cells: 9
# Epoch 1/200
# 20/20 - 7s - loss: 0.4580 - accuracy: 0.7906 - val_loss: 0.3102 - val_accuracy: 0.8625 - 7s/epoch - 366ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2622 - accuracy: 0.9031 - val_loss: 0.1723 - val_accuracy: 0.9250 - 495ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1715 - accuracy: 0.9438 - val_loss: 0.1403 - val_accuracy: 0.9250 - 429ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1256 - accuracy: 0.9625 - val_loss: 0.1649 - val_accuracy: 0.9750 - 428ms/epoch - 21ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1426 - accuracy: 0.9531 - val_loss: 0.1836 - val_accuracy: 0.9500 - 409ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0796 - accuracy: 0.9812 - val_loss: 0.1565 - val_accuracy: 0.9500 - 410ms/epoch - 21ms/step
