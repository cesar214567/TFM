# %% [markdown]
# # Violence Detection using CNN + LSTM neural netowrk

# %% [markdown]
# ## Introduction

# %% [markdown]
# Today, the amount of public violence has increased dramatically. As much in high schools as in the street. This has resulted in the ubiquitous use of surveillance cameras. This has helped the authorities to identify these events and take the necessary measures. But almost all systems today require the human-inspection of these videos to identify such events, which is virtually inefficient. It is therefore necessary to have such a practical system that can automatically monitor and identify the surveillance videos.
# The development of various deep learning techniques, thanks to the availability of large data sets and computational resources, has resulted in a historic change in the community of computer vision. Various techniques have been developed to address problems such as object detection, recognition, tracking, action recognition, legend generation, etc. However, despite recent developments in deep learning, very few techniques based on deep learning have been proposed to address the problem of detecting violence from videos.

# %% [markdown]
# ## Flowchart

# %% [markdown]
# The method consists of extracting a set of frames belonging to the video, sending them to a pretrained network called VGG16, obtaining the output of one of its final layers and from these outputs train another network architecture with a type of special neurons called LSTM. These neurons have memory and are able to analyze the temporal information of the video, if at any time they detect violence, it will be classified as a violent video.

# %% [markdown]
# ## Imports

# %%
#!pip install kagglehub

# %%
# %matplotlib inline
import cv2
import os
import numpy as np
import keras
import matplotlib.pyplot as plt
import kagglehub
import shutil

# import download
from random import shuffle
import tensorflow as tf
from tensorflow.keras.applications.efficientnet import EfficientNetB0
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Activation, GlobalAveragePooling2D, Flatten

import sys
import h5py

current_dir = os.getcwd()
print(current_dir)
sys.path.append(current_dir+'/utils')
from utils.datamanager import download_dataset, label_video_names
# Out:
# c:\Users\Cesar\Desktop\maestria\TFM

# %% [markdown]
# ## Check if gpu enabled

# %%
# Check if TensorFlow can see a GPU
gpus = tf.config.list_physical_devices('GPU')
print("Num GPUs Available:", len(gpus))
print("GPU Details:", gpus)
# Out:
# Num GPUs Available: 1
# GPU Details: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Download dataset

# %%
current_dir = os.getcwd()

download_dataset(current_dir)
# Out:
# Dataset copied to: c:\Users\Cesar\Desktop\maestria\TFM

# %% [markdown]
# ## Load Data
#
# Firstly, we define the directory to place the video dataset

# %%
in_dir = "data"

# %% [markdown]
# Copy some of the data-dimensions for convenience.

# %%
# Frame size  
img_size = 224

img_size_touple = (img_size, img_size)

# Number of channels (RGB)
num_channels = 3

img_size_tiplet = (img_size, img_size,num_channels)

# Flat frame size
img_size_flat = img_size * img_size * num_channels

# Number of classes for classification (Violence-No Violence)
num_classes = 2

frames_per_file = 10
_images_per_file = frames_per_file


# Video extension
video_exts = ".avi"

# %% [markdown]
# In order to load the saved transfer values into RAM memory we are going to use this two functions:

# %%
def process_alldata(file):
    
    joint_transfer=[]
    frames_num=20
    count = 0
    
    with h5py.File(file, 'r') as f:
            
        X_batch = f['data'][:]
        y_batch = f['labels'][:]

    for i in range(int(len(X_batch)/frames_num)):
        inc = count+frames_num
        joint_transfer.append([X_batch[count:inc],y_batch[count]])
        count =inc
        
    data =[]
    target=[]
    
    for i in joint_transfer:
        data.append(i[0])
        target.append(np.array(i[1]))
        
    return data, target

# %% [markdown]
# ##Recurrent Neural Network

# %% [markdown]
# The basic building block in a Recurrent Neural Network (RNN) is a Recurrent Unit (RU). There are many different variants of recurrent units such as the rather clunky LSTM (Long-Short-Term-Memory) and the somewhat simpler GRU (Gated Recurrent Unit) which we will use in this tutorial. Experiments in the literature suggest that the LSTM and GRU have roughly similar performance. Even simpler variants also exist and the literature suggests that they may perform even better than both LSTM and GRU, but they are not implemented in Keras which we will use in this tutorial.
#
# A recurrent neuron has an internal state that is being updated every time the unit receives a new input. This internal state serves as a kind of memory. However, it is not a traditional kind of computer memory which stores bits that are either on or off. Instead the recurrent unit stores floating-point values in its memory-state, which are read and written using matrix-operations so the operations are all differentiable. This means the memory-state can store arbitrary floating-point values (although typically limited between -1.0 and 1.0) and the network can be trained like a normal neural network using Gradient Descent.

# %% [markdown]
# ### Define LSTM architecture

# %% [markdown]
# When defining the LSTM architecture we have to take into account the dimensions of the transfer values. From each frame the VGG16 network obtains as output a vector of 4096 transfer values. From each video we are processing 20 frames so we will have 20 x 4096 values per video. The classification must be done taking into account the 20 frames of the video. If any of them detects violence, the video will be classified as violent.

# %% [markdown]
# The first input dimension of LSTM neurons is the temporal dimension, in our case it is 20. The second is the size of the features vector (transfer values).

# %%
n_chunks = _images_per_file

from keras import backend as K

def f1_score(y_true, y_pred):
    y_pred = K.round(y_pred)  # Round to 0 or 1
    tp = K.sum(K.cast(y_true * y_pred, 'float'), axis=0)
    fp = K.sum(K.cast((1 - y_true) * y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true * (1 - y_pred), 'float'), axis=0)

    precision = tp / (tp + fp + K.epsilon())
    recall = tp / (tp + fn + K.epsilon())
    
    f1 = 2 * precision * recall / (precision + recall + K.epsilon())
    return K.mean(f1)

def getLSTM(cells,chunk_size):
    model = Sequential()
    model.add(Bidirectional(LSTM(cells, input_shape=(n_chunks, chunk_size))))
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dense(50))
    model.add(Activation('relu'))
    model.add(Dense(2))
    model.add(Activation('softmax'))
    model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy',f1_score])
    return model

# %% [markdown]
# ## Model training

# %%
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    min_delta=0.005,          # training stops if val_loss improves less than 0.001
    restore_best_weights=True
)

def train_model(data, target, input_size, cells, batchs = 16, epochs=200):
    model = getLSTM(cells,input_size)
    X_train, X_val, y_train, y_val = train_test_split(data, target, test_size=0.2, random_state=42)
    history = model.fit(np.array(X_train), np.array(y_train), epochs=epochs,
                        validation_data=(np.array(X_val), np.array(y_val)), 
                        batch_size=batchs, verbose=2, callbacks=[early_stopping])
    return model, history

# %% [markdown]
# ## Test the model and print results

# %% [markdown]
# We are going to test the model with 20 % of the total videos. This videos have not been used to train the network.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Directorios
script_dir = os.getcwd()
training_dir = os.path.join(script_dir, "processedData/training/")
testing_dir = os.path.join(script_dir, "processedData/testing/")
graphs_dir = os.path.join(script_dir, "graphs/")
os.makedirs(graphs_dir, exist_ok=True)

# Rango de LSTM cells
cells_start = 1
cells_end = 10
cells_list = list(range(cells_start, cells_end))  # 1 to 9 cells

# Iterar sobre cada modelo CNN
for filename in os.listdir(training_dir):
    print(f"Processing CNN Model: {filename}")
    cnn_name = filename.split('.')[0]  # Nombre base para gráficas/CSV

    # Cargar datos
    data, target = process_alldata(os.path.join(training_dir, filename))
    data_test, target_test = process_alldata(os.path.join(testing_dir, filename))

    model_metrics = []   # Por época (para gráficas)
    final_metrics = []   # Solo última época (para CSV)

    for cells in cells_list:
        print(f"  → LSTM cells: {cells}")
        model, history = train_model(data, target, data[0].shape[1], cells)

        # Guardar métricas por época para graficar
        epochs = range(1, len(history.history['loss']) + 1)
        for i, epoch in enumerate(epochs):
            model_metrics.append({
                'cnn_model': cnn_name,
                'lstm_cells': cells,
                'epoch': epoch,
                'train_loss': history.history['loss'][i],
                'train_f1': history.history['f1_score'][i],
                'val_loss': history.history['val_loss'][i],
                'val_f1': history.history['val_f1_score'][i]
            })

        # Guardar solo la última época para el CSV final
        train_loss = round(history.history['loss'][-1], 4)
        train_f1 = round(history.history['f1_score'][-1], 4)
        val_loss = round(history.history['val_loss'][-1], 4)
        val_f1 = round(history.history['val_f1_score'][-1], 4)
        test_loss, test_f1 = model.evaluate(np.array(data_test), np.array(target_test), verbose=0)[:2]
        test_loss, test_f1 = round(test_loss, 4), round(test_f1, 4)

        final_metrics.append({
            'cnn_model': cnn_name,
            'lstm_cells': cells,
            'train_loss': train_loss,
            'train_f1': train_f1,
            'val_loss': val_loss,
            'val_f1': val_f1,
            'test_loss': test_loss,
            'test_f1': test_f1
        })

    # Guardar CSV final solo con última época
    df_final = pd.DataFrame(final_metrics)
    df_final.to_csv(os.path.join(graphs_dir, f"{cnn_name}_metrics.csv"), index=False)

    # Convertir a DataFrame para gráficas
    df_model = pd.DataFrame(model_metrics)

    # Graficar curvas por época y celdas - Validation Loss
    plt.figure(figsize=(10, 6))
    for cells in df_model['lstm_cells'].unique():
        subset = df_model[df_model['lstm_cells'] == cells]
        plt.plot(subset['epoch'], subset['val_loss'], label=f'{cells} cells')
    plt.title(f'Validation Loss vs Epochs - {cnn_name}')
    plt.xlabel('Epoch')
    plt.ylabel('Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join(graphs_dir, f"{cnn_name}_val_loss_per_epoch.png"), dpi=300)
    plt.close()

    # Graficar curvas por época y celdas - Validation F1 Score
    plt.figure(figsize=(10, 6))
    for cells in df_model['lstm_cells'].unique():
        subset = df_model[df_model['lstm_cells'] == cells]
        plt.plot(subset['epoch'], subset['val_f1'], label=f'{cells} cells')
    plt.title(f'Validation F1 Score vs Epochs - {cnn_name}')
    plt.xlabel('Epoch')
    plt.ylabel('Validation F1 Score')
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join(graphs_dir, f"{cnn_name}_val_f1_per_epoch.png"), dpi=300)
    plt.close()
# Out:
# Processing CNN Model: efficientnetb0.h5
#   → LSTM cells: 1
# Epoch 1/200
# 20/20 - 7s - loss: 0.6921 - accuracy: 0.5844 - f1_score: 0.5513 - val_loss: 0.6667 - val_accuracy: 0.8375 - val_f1_score: 0.8219 - 7s/epoch - 342ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.5210 - accuracy: 0.8750 - f1_score: 0.8664 - val_loss: 0.3452 - val_accuracy: 0.9250 - val_f1_score: 0.9141 - 450ms/epoch - 23ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2793 - accuracy: 0.9156 - f1_score: 0.9035 - val_loss: 0.2712 - val_accuracy: 0.9125 - val_f1_score: 0.9031 - 439ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1793 - accuracy: 0.9563 - f1_score: 0.9552 - val_loss: 0.2682 - val_accuracy: 0.9375 - val_f1_score: 0.9278 - 418ms/epoch - 21ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1479 - accuracy: 0.9563 - f1_score: 0.9540 - val_loss: 0.2523 - val_accuracy: 0.9125 - val_f1_score: 0.9031 - 351ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1060 - accuracy: 0.9750 - f1_score: 0.9745 - val_loss: 0.2465 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 355ms/epoch - 18ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0809 - accuracy: 0.9750 - f1_score: 0.9742 - val_loss: 0.2283 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 358ms/epoch - 18ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0861 - accuracy: 0.9781 - f1_score: 0.9773 - val_loss: 0.2375 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 347ms/epoch - 17ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0519 - accuracy: 0.9812 - f1_score: 0.9800 - val_loss: 0.2298 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 348ms/epoch - 17ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0347 - accuracy: 0.9875 - f1_score: 0.9873 - val_loss: 0.2488 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 359ms/epoch - 18ms/step
#   → LSTM cells: 2
# Epoch 1/200
# 20/20 - 7s - loss: 0.5799 - accuracy: 0.7875 - f1_score: 0.7674 - val_loss: 0.3426 - val_accuracy: 0.9250 - val_f1_score: 0.9143 - 7s/epoch - 329ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2278 - accuracy: 0.9406 - f1_score: 0.9391 - val_loss: 0.1916 - val_accuracy: 0.9250 - val_f1_score: 0.9145 - 522ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 1s - loss: 0.1710 - accuracy: 0.9531 - f1_score: 0.9489 - val_loss: 0.1951 - val_accuracy: 0.9375 - val_f1_score: 0.9273 - 513ms/epoch - 26ms/step
# Epoch 4/200
# 20/20 - 1s - loss: 0.1112 - accuracy: 0.9656 - f1_score: 0.9643 - val_loss: 0.2209 - val_accuracy: 0.9375 - val_f1_score: 0.9311 - 502ms/epoch - 25ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1213 - accuracy: 0.9625 - f1_score: 0.9564 - val_loss: 0.2392 - val_accuracy: 0.9500 - val_f1_score: 0.9399 - 434ms/epoch - 22ms/step
#   → LSTM cells: 3
# Epoch 1/200
# 20/20 - 7s - loss: 0.5072 - accuracy: 0.8594 - f1_score: 0.8505 - val_loss: 0.2569 - val_accuracy: 0.9250 - val_f1_score: 0.9183 - 7s/epoch - 326ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2227 - accuracy: 0.9281 - f1_score: 0.9260 - val_loss: 0.2694 - val_accuracy: 0.9250 - val_f1_score: 0.9174 - 543ms/epoch - 27ms/step
# Epoch 3/200
# 20/20 - 1s - loss: 0.1687 - accuracy: 0.9531 - f1_score: 0.9491 - val_loss: 0.1438 - val_accuracy: 0.9625 - val_f1_score: 0.9580 - 521ms/epoch - 26ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1204 - accuracy: 0.9656 - f1_score: 0.9634 - val_loss: 0.1493 - val_accuracy: 0.9375 - val_f1_score: 0.9287 - 434ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0761 - accuracy: 0.9688 - f1_score: 0.9674 - val_loss: 0.1318 - val_accuracy: 0.9750 - val_f1_score: 0.9720 - 403ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0513 - accuracy: 0.9875 - f1_score: 0.9861 - val_loss: 0.1954 - val_accuracy: 0.9375 - val_f1_score: 0.9311 - 397ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0315 - accuracy: 0.9906 - f1_score: 0.9888 - val_loss: 0.1676 - val_accuracy: 0.9625 - val_f1_score: 0.9580 - 393ms/epoch - 20ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0209 - accuracy: 0.9937 - f1_score: 0.9902 - val_loss: 0.1862 - val_accuracy: 0.9625 - val_f1_score: 0.9580 - 390ms/epoch - 20ms/step
#   → LSTM cells: 4
# Epoch 1/200
# 20/20 - 6s - loss: 0.5248 - accuracy: 0.8125 - f1_score: 0.8075 - val_loss: 0.2106 - val_accuracy: 0.9375 - val_f1_score: 0.9277 - 6s/epoch - 303ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2349 - accuracy: 0.9125 - f1_score: 0.9061 - val_loss: 0.1418 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 529ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1856 - accuracy: 0.9438 - f1_score: 0.9406 - val_loss: 0.1072 - val_accuracy: 0.9625 - val_f1_score: 0.9541 - 472ms/epoch - 24ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1204 - accuracy: 0.9531 - f1_score: 0.9518 - val_loss: 0.1035 - val_accuracy: 0.9750 - val_f1_score: 0.9720 - 382ms/epoch - 19ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0676 - accuracy: 0.9844 - f1_score: 0.9842 - val_loss: 0.1428 - val_accuracy: 0.9625 - val_f1_score: 0.9577 - 383ms/epoch - 19ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0470 - accuracy: 0.9937 - f1_score: 0.9929 - val_loss: 0.1038 - val_accuracy: 0.9625 - val_f1_score: 0.9541 - 393ms/epoch - 20ms/step
#   → LSTM cells: 5
# Epoch 1/200
# 20/20 - 7s - loss: 0.5311 - accuracy: 0.7781 - f1_score: 0.7249 - val_loss: 0.2545 - val_accuracy: 0.9375 - val_f1_score: 0.9332 - 7s/epoch - 333ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2984 - accuracy: 0.9156 - f1_score: 0.9061 - val_loss: 0.1636 - val_accuracy: 0.9250 - val_f1_score: 0.9195 - 533ms/epoch - 27ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1865 - accuracy: 0.9406 - f1_score: 0.9365 - val_loss: 0.2541 - val_accuracy: 0.9000 - val_f1_score: 0.8915 - 480ms/epoch - 24ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1399 - accuracy: 0.9563 - f1_score: 0.9548 - val_loss: 0.1421 - val_accuracy: 0.9625 - val_f1_score: 0.9541 - 400ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1248 - accuracy: 0.9688 - f1_score: 0.9676 - val_loss: 0.1569 - val_accuracy: 0.9625 - val_f1_score: 0.9590 - 386ms/epoch - 19ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0985 - accuracy: 0.9719 - f1_score: 0.9700 - val_loss: 0.1956 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 381ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0580 - accuracy: 0.9812 - f1_score: 0.9790 - val_loss: 0.1506 - val_accuracy: 0.9625 - val_f1_score: 0.9581 - 392ms/epoch - 20ms/step
#   → LSTM cells: 6
# Epoch 1/200
# 20/20 - 6s - loss: 0.5173 - accuracy: 0.7969 - f1_score: 0.7544 - val_loss: 0.2297 - val_accuracy: 0.9125 - val_f1_score: 0.9025 - 6s/epoch - 301ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2294 - accuracy: 0.9281 - f1_score: 0.9235 - val_loss: 0.1716 - val_accuracy: 0.9625 - val_f1_score: 0.9577 - 535ms/epoch - 27ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1672 - accuracy: 0.9500 - f1_score: 0.9439 - val_loss: 0.1723 - val_accuracy: 0.9375 - val_f1_score: 0.9282 - 438ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1329 - accuracy: 0.9625 - f1_score: 0.9605 - val_loss: 0.1448 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 407ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0747 - accuracy: 0.9781 - f1_score: 0.9772 - val_loss: 0.1457 - val_accuracy: 0.9625 - val_f1_score: 0.9541 - 401ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0452 - accuracy: 0.9844 - f1_score: 0.9842 - val_loss: 0.2040 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 398ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0290 - accuracy: 0.9937 - f1_score: 0.9931 - val_loss: 0.1599 - val_accuracy: 0.9625 - val_f1_score: 0.9541 - 405ms/epoch - 20ms/step
#   → LSTM cells: 7
# Epoch 1/200
# 20/20 - 6s - loss: 0.4906 - accuracy: 0.8219 - f1_score: 0.7921 - val_loss: 0.2378 - val_accuracy: 0.8750 - val_f1_score: 0.8635 - 6s/epoch - 307ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2364 - accuracy: 0.9281 - f1_score: 0.9247 - val_loss: 0.1774 - val_accuracy: 0.9375 - val_f1_score: 0.9313 - 567ms/epoch - 28ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1415 - accuracy: 0.9688 - f1_score: 0.9680 - val_loss: 0.1586 - val_accuracy: 0.9375 - val_f1_score: 0.9311 - 494ms/epoch - 25ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1275 - accuracy: 0.9594 - f1_score: 0.9582 - val_loss: 0.1968 - val_accuracy: 0.9125 - val_f1_score: 0.9049 - 397ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0876 - accuracy: 0.9750 - f1_score: 0.9737 - val_loss: 0.1201 - val_accuracy: 0.9750 - val_f1_score: 0.9667 - 410ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0551 - accuracy: 0.9906 - f1_score: 0.9890 - val_loss: 0.1251 - val_accuracy: 0.9750 - val_f1_score: 0.9667 - 384ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0407 - accuracy: 0.9937 - f1_score: 0.9931 - val_loss: 0.1308 - val_accuracy: 0.9625 - val_f1_score: 0.9541 - 391ms/epoch - 20ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0258 - accuracy: 0.9937 - f1_score: 0.9933 - val_loss: 0.1367 - val_accuracy: 0.9625 - val_f1_score: 0.9541 - 401ms/epoch - 20ms/step
#   → LSTM cells: 8
# Epoch 1/200
# 20/20 - 6s - loss: 0.5162 - accuracy: 0.8062 - f1_score: 0.7838 - val_loss: 0.2496 - val_accuracy: 0.9250 - val_f1_score: 0.9195 - 6s/epoch - 320ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2275 - accuracy: 0.9375 - f1_score: 0.9329 - val_loss: 0.1735 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 481ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1807 - accuracy: 0.9312 - f1_score: 0.9278 - val_loss: 0.1259 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 402ms/epoch - 20ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1093 - accuracy: 0.9656 - f1_score: 0.9591 - val_loss: 0.1332 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 388ms/epoch - 19ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0634 - accuracy: 0.9812 - f1_score: 0.9783 - val_loss: 0.1277 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 392ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0214 - accuracy: 0.9937 - f1_score: 0.9929 - val_loss: 0.2205 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 414ms/epoch - 21ms/step
#   → LSTM cells: 9
# Epoch 1/200
# 20/20 - 6s - loss: 0.4739 - accuracy: 0.8031 - f1_score: 0.7732 - val_loss: 0.2258 - val_accuracy: 0.9375 - val_f1_score: 0.9287 - 6s/epoch - 307ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2282 - accuracy: 0.9344 - f1_score: 0.9297 - val_loss: 0.1568 - val_accuracy: 0.9500 - val_f1_score: 0.9417 - 493ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1624 - accuracy: 0.9438 - f1_score: 0.9383 - val_loss: 0.1547 - val_accuracy: 0.9500 - val_f1_score: 0.9417 - 404ms/epoch - 20ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.0934 - accuracy: 0.9719 - f1_score: 0.9704 - val_loss: 0.2001 - val_accuracy: 0.9375 - val_f1_score: 0.9291 - 404ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0792 - accuracy: 0.9750 - f1_score: 0.9735 - val_loss: 0.1322 - val_accuracy: 0.9750 - val_f1_score: 0.9667 - 407ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0523 - accuracy: 0.9750 - f1_score: 0.9725 - val_loss: 0.1282 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 408ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0299 - accuracy: 0.9937 - f1_score: 0.9936 - val_loss: 0.1935 - val_accuracy: 0.9375 - val_f1_score: 0.9287 - 402ms/epoch - 20ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0120 - accuracy: 0.9969 - f1_score: 0.9961 - val_loss: 0.1564 - val_accuracy: 0.9750 - val_f1_score: 0.9667 - 410ms/epoch - 20ms/step
# Processing CNN Model: efficientnetv2-s.h5
#   → LSTM cells: 1
# Epoch 1/200
# 20/20 - 7s - loss: 0.6303 - accuracy: 0.7344 - f1_score: 0.7074 - val_loss: 0.4340 - val_accuracy: 0.9375 - val_f1_score: 0.9326 - 7s/epoch - 358ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.3261 - accuracy: 0.9156 - f1_score: 0.9095 - val_loss: 0.2422 - val_accuracy: 0.9125 - val_f1_score: 0.9034 - 478ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 1s - loss: 0.2415 - accuracy: 0.9219 - f1_score: 0.9153 - val_loss: 0.2062 - val_accuracy: 0.9250 - val_f1_score: 0.9183 - 546ms/epoch - 27ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1862 - accuracy: 0.9500 - f1_score: 0.9458 - val_loss: 0.1859 - val_accuracy: 0.9500 - val_f1_score: 0.9449 - 440ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1615 - accuracy: 0.9594 - f1_score: 0.9556 - val_loss: 0.1607 - val_accuracy: 0.9375 - val_f1_score: 0.9320 - 431ms/epoch - 22ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1389 - accuracy: 0.9656 - f1_score: 0.9638 - val_loss: 0.1703 - val_accuracy: 0.9500 - val_f1_score: 0.9441 - 378ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1215 - accuracy: 0.9719 - f1_score: 0.9701 - val_loss: 0.1534 - val_accuracy: 0.9500 - val_f1_score: 0.9449 - 331ms/epoch - 17ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.1318 - accuracy: 0.9625 - f1_score: 0.9608 - val_loss: 0.1705 - val_accuracy: 0.9375 - val_f1_score: 0.9320 - 327ms/epoch - 16ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.1119 - accuracy: 0.9625 - f1_score: 0.9607 - val_loss: 0.2253 - val_accuracy: 0.9375 - val_f1_score: 0.9320 - 329ms/epoch - 16ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0833 - accuracy: 0.9719 - f1_score: 0.9693 - val_loss: 0.2338 - val_accuracy: 0.9375 - val_f1_score: 0.9320 - 343ms/epoch - 17ms/step
#   → LSTM cells: 2
# Epoch 1/200
# 20/20 - 6s - loss: 0.5941 - accuracy: 0.7469 - f1_score: 0.7045 - val_loss: 0.3943 - val_accuracy: 0.8750 - val_f1_score: 0.8692 - 6s/epoch - 320ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.3232 - accuracy: 0.8875 - f1_score: 0.8801 - val_loss: 0.2415 - val_accuracy: 0.9250 - val_f1_score: 0.9164 - 523ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2317 - accuracy: 0.9281 - f1_score: 0.9226 - val_loss: 0.3741 - val_accuracy: 0.8875 - val_f1_score: 0.8773 - 470ms/epoch - 24ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.2461 - accuracy: 0.9250 - f1_score: 0.9174 - val_loss: 0.2322 - val_accuracy: 0.9250 - val_f1_score: 0.9171 - 388ms/epoch - 19ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1693 - accuracy: 0.9531 - f1_score: 0.9509 - val_loss: 0.1592 - val_accuracy: 0.9500 - val_f1_score: 0.9462 - 383ms/epoch - 19ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1508 - accuracy: 0.9531 - f1_score: 0.9481 - val_loss: 0.1514 - val_accuracy: 0.9500 - val_f1_score: 0.9462 - 387ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1227 - accuracy: 0.9688 - f1_score: 0.9671 - val_loss: 0.1541 - val_accuracy: 0.9500 - val_f1_score: 0.9449 - 381ms/epoch - 19ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0897 - accuracy: 0.9781 - f1_score: 0.9764 - val_loss: 0.1316 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 389ms/epoch - 19ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0755 - accuracy: 0.9812 - f1_score: 0.9796 - val_loss: 0.1852 - val_accuracy: 0.9500 - val_f1_score: 0.9448 - 456ms/epoch - 23ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0585 - accuracy: 0.9875 - f1_score: 0.9862 - val_loss: 0.1488 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 374ms/epoch - 19ms/step
# Epoch 11/200
# 20/20 - 0s - loss: 0.0480 - accuracy: 0.9875 - f1_score: 0.9869 - val_loss: 0.1492 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 381ms/epoch - 19ms/step
#   → LSTM cells: 3
# Epoch 1/200
# 20/20 - 6s - loss: 0.5264 - accuracy: 0.8156 - f1_score: 0.8057 - val_loss: 0.2926 - val_accuracy: 0.8875 - val_f1_score: 0.8761 - 6s/epoch - 293ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2726 - accuracy: 0.9094 - f1_score: 0.9039 - val_loss: 0.2093 - val_accuracy: 0.9000 - val_f1_score: 0.8862 - 518ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1990 - accuracy: 0.9219 - f1_score: 0.9160 - val_loss: 0.2110 - val_accuracy: 0.9375 - val_f1_score: 0.9286 - 453ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1891 - accuracy: 0.9281 - f1_score: 0.9236 - val_loss: 0.3147 - val_accuracy: 0.8750 - val_f1_score: 0.8559 - 380ms/epoch - 19ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1850 - accuracy: 0.9375 - f1_score: 0.9349 - val_loss: 0.3138 - val_accuracy: 0.8875 - val_f1_score: 0.8779 - 387ms/epoch - 19ms/step
#   → LSTM cells: 4
# Epoch 1/200
# 20/20 - 6s - loss: 0.5766 - accuracy: 0.7625 - f1_score: 0.7117 - val_loss: 0.3325 - val_accuracy: 0.9250 - val_f1_score: 0.9158 - 6s/epoch - 311ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2865 - accuracy: 0.9094 - f1_score: 0.9038 - val_loss: 0.2296 - val_accuracy: 0.9250 - val_f1_score: 0.9195 - 483ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2471 - accuracy: 0.9156 - f1_score: 0.9118 - val_loss: 0.3052 - val_accuracy: 0.8875 - val_f1_score: 0.8775 - 379ms/epoch - 19ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1826 - accuracy: 0.9438 - f1_score: 0.9405 - val_loss: 0.1618 - val_accuracy: 0.9375 - val_f1_score: 0.9320 - 404ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1280 - accuracy: 0.9625 - f1_score: 0.9593 - val_loss: 0.1619 - val_accuracy: 0.9500 - val_f1_score: 0.9452 - 410ms/epoch - 21ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0877 - accuracy: 0.9750 - f1_score: 0.9734 - val_loss: 0.1812 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 410ms/epoch - 21ms/step
# Epoch 7/200
# 20/20 - 1s - loss: 0.1111 - accuracy: 0.9625 - f1_score: 0.9605 - val_loss: 0.2680 - val_accuracy: 0.9250 - val_f1_score: 0.9187 - 524ms/epoch - 26ms/step
#   → LSTM cells: 5
# Epoch 1/200
# 20/20 - 6s - loss: 0.5938 - accuracy: 0.8000 - f1_score: 0.7636 - val_loss: 0.3471 - val_accuracy: 0.9000 - val_f1_score: 0.8896 - 6s/epoch - 294ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2783 - accuracy: 0.9094 - f1_score: 0.9017 - val_loss: 0.2114 - val_accuracy: 0.9125 - val_f1_score: 0.9029 - 519ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2063 - accuracy: 0.9344 - f1_score: 0.9288 - val_loss: 0.1848 - val_accuracy: 0.9375 - val_f1_score: 0.9287 - 438ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1380 - accuracy: 0.9563 - f1_score: 0.9535 - val_loss: 0.1885 - val_accuracy: 0.9250 - val_f1_score: 0.9158 - 385ms/epoch - 19ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1147 - accuracy: 0.9594 - f1_score: 0.9574 - val_loss: 0.1658 - val_accuracy: 0.9500 - val_f1_score: 0.9452 - 380ms/epoch - 19ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1054 - accuracy: 0.9688 - f1_score: 0.9682 - val_loss: 0.1580 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 383ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0882 - accuracy: 0.9750 - f1_score: 0.9726 - val_loss: 0.1212 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 388ms/epoch - 19ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0451 - accuracy: 0.9906 - f1_score: 0.9905 - val_loss: 0.1416 - val_accuracy: 0.9500 - val_f1_score: 0.9400 - 382ms/epoch - 19ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0292 - accuracy: 0.9937 - f1_score: 0.9936 - val_loss: 0.1511 - val_accuracy: 0.9500 - val_f1_score: 0.9400 - 385ms/epoch - 19ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0228 - accuracy: 0.9937 - f1_score: 0.9936 - val_loss: 0.1915 - val_accuracy: 0.9375 - val_f1_score: 0.9270 - 382ms/epoch - 19ms/step
#   → LSTM cells: 6
# Epoch 1/200
# 20/20 - 6s - loss: 0.5772 - accuracy: 0.7375 - f1_score: 0.7062 - val_loss: 0.3657 - val_accuracy: 0.8875 - val_f1_score: 0.8760 - 6s/epoch - 307ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2629 - accuracy: 0.9125 - f1_score: 0.9082 - val_loss: 0.3357 - val_accuracy: 0.8375 - val_f1_score: 0.8036 - 500ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2031 - accuracy: 0.9312 - f1_score: 0.9244 - val_loss: 0.1833 - val_accuracy: 0.9500 - val_f1_score: 0.9457 - 426ms/epoch - 21ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1250 - accuracy: 0.9625 - f1_score: 0.9608 - val_loss: 0.1620 - val_accuracy: 0.9500 - val_f1_score: 0.9457 - 418ms/epoch - 21ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0919 - accuracy: 0.9781 - f1_score: 0.9775 - val_loss: 0.2038 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 405ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 1s - loss: 0.0827 - accuracy: 0.9750 - f1_score: 0.9737 - val_loss: 0.1456 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 503ms/epoch - 25ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0597 - accuracy: 0.9844 - f1_score: 0.9819 - val_loss: 0.1443 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 425ms/epoch - 21ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0511 - accuracy: 0.9844 - f1_score: 0.9816 - val_loss: 0.1683 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 460ms/epoch - 23ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0396 - accuracy: 0.9875 - f1_score: 0.9875 - val_loss: 0.1626 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 424ms/epoch - 21ms/step
#   → LSTM cells: 7
# Epoch 1/200
# 20/20 - 8s - loss: 0.5813 - accuracy: 0.7281 - f1_score: 0.6680 - val_loss: 0.3277 - val_accuracy: 0.8625 - val_f1_score: 0.8506 - 8s/epoch - 382ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2561 - accuracy: 0.9250 - f1_score: 0.9239 - val_loss: 0.2741 - val_accuracy: 0.9250 - val_f1_score: 0.9159 - 569ms/epoch - 28ms/step
# Epoch 3/200
# 20/20 - 1s - loss: 0.1711 - accuracy: 0.9469 - f1_score: 0.9426 - val_loss: 0.1708 - val_accuracy: 0.9500 - val_f1_score: 0.9449 - 521ms/epoch - 26ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1798 - accuracy: 0.9469 - f1_score: 0.9427 - val_loss: 0.1901 - val_accuracy: 0.9500 - val_f1_score: 0.9448 - 398ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1074 - accuracy: 0.9625 - f1_score: 0.9597 - val_loss: 0.3412 - val_accuracy: 0.9125 - val_f1_score: 0.9034 - 392ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1473 - accuracy: 0.9438 - f1_score: 0.9402 - val_loss: 0.2269 - val_accuracy: 0.9375 - val_f1_score: 0.9320 - 409ms/epoch - 20ms/step
#   → LSTM cells: 8
# Epoch 1/200
# 20/20 - 6s - loss: 0.5538 - accuracy: 0.7563 - f1_score: 0.7073 - val_loss: 0.3374 - val_accuracy: 0.8500 - val_f1_score: 0.8399 - 6s/epoch - 298ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2699 - accuracy: 0.9094 - f1_score: 0.9027 - val_loss: 0.2023 - val_accuracy: 0.9250 - val_f1_score: 0.9141 - 497ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2240 - accuracy: 0.9406 - f1_score: 0.9381 - val_loss: 0.1979 - val_accuracy: 0.9375 - val_f1_score: 0.9270 - 397ms/epoch - 20ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1712 - accuracy: 0.9469 - f1_score: 0.9447 - val_loss: 0.1708 - val_accuracy: 0.9250 - val_f1_score: 0.9145 - 392ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1359 - accuracy: 0.9594 - f1_score: 0.9568 - val_loss: 0.1784 - val_accuracy: 0.9500 - val_f1_score: 0.9449 - 390ms/epoch - 19ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0820 - accuracy: 0.9750 - f1_score: 0.9725 - val_loss: 0.1845 - val_accuracy: 0.9375 - val_f1_score: 0.9270 - 384ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0504 - accuracy: 0.9875 - f1_score: 0.9872 - val_loss: 0.1829 - val_accuracy: 0.9250 - val_f1_score: 0.9139 - 402ms/epoch - 20ms/step
#   → LSTM cells: 9
# Epoch 1/200
# 20/20 - 6s - loss: 0.4973 - accuracy: 0.7937 - f1_score: 0.7690 - val_loss: 0.2571 - val_accuracy: 0.8875 - val_f1_score: 0.8785 - 6s/epoch - 318ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.3052 - accuracy: 0.9031 - f1_score: 0.8965 - val_loss: 0.1997 - val_accuracy: 0.9125 - val_f1_score: 0.9046 - 504ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1976 - accuracy: 0.9438 - f1_score: 0.9409 - val_loss: 0.2437 - val_accuracy: 0.9125 - val_f1_score: 0.9034 - 399ms/epoch - 20ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1815 - accuracy: 0.9406 - f1_score: 0.9356 - val_loss: 0.1653 - val_accuracy: 0.9375 - val_f1_score: 0.9282 - 406ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1584 - accuracy: 0.9469 - f1_score: 0.9411 - val_loss: 0.1816 - val_accuracy: 0.9375 - val_f1_score: 0.9324 - 410ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1085 - accuracy: 0.9719 - f1_score: 0.9699 - val_loss: 0.1869 - val_accuracy: 0.9375 - val_f1_score: 0.9324 - 396ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0729 - accuracy: 0.9781 - f1_score: 0.9764 - val_loss: 0.1489 - val_accuracy: 0.9500 - val_f1_score: 0.9452 - 406ms/epoch - 20ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0493 - accuracy: 0.9875 - f1_score: 0.9863 - val_loss: 0.1692 - val_accuracy: 0.9500 - val_f1_score: 0.9461 - 390ms/epoch - 20ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0320 - accuracy: 0.9906 - f1_score: 0.9904 - val_loss: 0.2427 - val_accuracy: 0.9375 - val_f1_score: 0.9336 - 388ms/epoch - 19ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0180 - accuracy: 0.9969 - f1_score: 0.9969 - val_loss: 0.2741 - val_accuracy: 0.9375 - val_f1_score: 0.9295 - 402ms/epoch - 20ms/step
# Processing CNN Model: MobilenetV3large.h5
#   → LSTM cells: 1
# Epoch 1/200
# 20/20 - 6s - loss: 0.6058 - accuracy: 0.7531 - f1_score: 0.7314 - val_loss: 0.3491 - val_accuracy: 0.9250 - val_f1_score: 0.9157 - 6s/epoch - 295ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.3038 - accuracy: 0.9062 - f1_score: 0.9004 - val_loss: 0.1699 - val_accuracy: 0.9500 - val_f1_score: 0.9461 - 412ms/epoch - 21ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2387 - accuracy: 0.9219 - f1_score: 0.9137 - val_loss: 0.1473 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 401ms/epoch - 20ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1924 - accuracy: 0.9469 - f1_score: 0.9448 - val_loss: 0.1553 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 396ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1694 - accuracy: 0.9563 - f1_score: 0.9541 - val_loss: 0.1482 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 404ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1660 - accuracy: 0.9594 - f1_score: 0.9551 - val_loss: 0.1344 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 398ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1484 - accuracy: 0.9625 - f1_score: 0.9612 - val_loss: 0.1282 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 398ms/epoch - 20ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.1328 - accuracy: 0.9625 - f1_score: 0.9600 - val_loss: 0.1336 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 393ms/epoch - 20ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.1191 - accuracy: 0.9719 - f1_score: 0.9707 - val_loss: 0.1194 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 396ms/epoch - 20ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.1114 - accuracy: 0.9781 - f1_score: 0.9752 - val_loss: 0.1149 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 382ms/epoch - 19ms/step
# Epoch 11/200
# 20/20 - 0s - loss: 0.0993 - accuracy: 0.9750 - f1_score: 0.9723 - val_loss: 0.1079 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 389ms/epoch - 19ms/step
# Epoch 12/200
# 20/20 - 0s - loss: 0.0901 - accuracy: 0.9812 - f1_score: 0.9799 - val_loss: 0.1163 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 382ms/epoch - 19ms/step
# Epoch 13/200
# 20/20 - 0s - loss: 0.0873 - accuracy: 0.9812 - f1_score: 0.9802 - val_loss: 0.1118 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 443ms/epoch - 22ms/step
# Epoch 14/200
# 20/20 - 0s - loss: 0.0732 - accuracy: 0.9844 - f1_score: 0.9796 - val_loss: 0.1027 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 401ms/epoch - 20ms/step
# Epoch 15/200
# 20/20 - 0s - loss: 0.0661 - accuracy: 0.9875 - f1_score: 0.9863 - val_loss: 0.1089 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 377ms/epoch - 19ms/step
# Epoch 16/200
# 20/20 - 0s - loss: 0.0613 - accuracy: 0.9844 - f1_score: 0.9840 - val_loss: 0.1008 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 382ms/epoch - 19ms/step
# Epoch 17/200
# 20/20 - 0s - loss: 0.0562 - accuracy: 0.9875 - f1_score: 0.9875 - val_loss: 0.1048 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 396ms/epoch - 20ms/step
#   → LSTM cells: 2
# Epoch 1/200
# 20/20 - 6s - loss: 0.5701 - accuracy: 0.7594 - f1_score: 0.7483 - val_loss: 0.3547 - val_accuracy: 0.8875 - val_f1_score: 0.8762 - 6s/epoch - 291ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.3276 - accuracy: 0.8938 - f1_score: 0.8865 - val_loss: 0.2881 - val_accuracy: 0.9125 - val_f1_score: 0.9010 - 496ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2776 - accuracy: 0.9156 - f1_score: 0.9088 - val_loss: 0.2652 - val_accuracy: 0.8875 - val_f1_score: 0.8768 - 466ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.2305 - accuracy: 0.9281 - f1_score: 0.9243 - val_loss: 0.2740 - val_accuracy: 0.9000 - val_f1_score: 0.8909 - 461ms/epoch - 23ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.2324 - accuracy: 0.9187 - f1_score: 0.9140 - val_loss: 0.2226 - val_accuracy: 0.9375 - val_f1_score: 0.9277 - 440ms/epoch - 22ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1810 - accuracy: 0.9281 - f1_score: 0.9253 - val_loss: 0.2364 - val_accuracy: 0.9125 - val_f1_score: 0.8991 - 408ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1220 - accuracy: 0.9531 - f1_score: 0.9490 - val_loss: 0.1683 - val_accuracy: 0.9500 - val_f1_score: 0.9399 - 380ms/epoch - 19ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0904 - accuracy: 0.9719 - f1_score: 0.9701 - val_loss: 0.1717 - val_accuracy: 0.9625 - val_f1_score: 0.9577 - 362ms/epoch - 18ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0556 - accuracy: 0.9906 - f1_score: 0.9883 - val_loss: 0.2233 - val_accuracy: 0.9250 - val_f1_score: 0.9159 - 361ms/epoch - 18ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0527 - accuracy: 0.9875 - f1_score: 0.9845 - val_loss: 0.2139 - val_accuracy: 0.9375 - val_f1_score: 0.9287 - 364ms/epoch - 18ms/step
#   → LSTM cells: 3
# Epoch 1/200
# 20/20 - 7s - loss: 0.5961 - accuracy: 0.7375 - f1_score: 0.7147 - val_loss: 0.3611 - val_accuracy: 0.8625 - val_f1_score: 0.8436 - 7s/epoch - 338ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2765 - accuracy: 0.8906 - f1_score: 0.8804 - val_loss: 0.2550 - val_accuracy: 0.9250 - val_f1_score: 0.9174 - 493ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2256 - accuracy: 0.9281 - f1_score: 0.9228 - val_loss: 0.1905 - val_accuracy: 0.9375 - val_f1_score: 0.9269 - 479ms/epoch - 24ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1622 - accuracy: 0.9531 - f1_score: 0.9487 - val_loss: 0.1321 - val_accuracy: 0.9375 - val_f1_score: 0.9283 - 447ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0923 - accuracy: 0.9688 - f1_score: 0.9672 - val_loss: 0.1443 - val_accuracy: 0.9500 - val_f1_score: 0.9413 - 367ms/epoch - 18ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0578 - accuracy: 0.9812 - f1_score: 0.9807 - val_loss: 0.1546 - val_accuracy: 0.9250 - val_f1_score: 0.9158 - 371ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0237 - accuracy: 0.9969 - f1_score: 0.9969 - val_loss: 0.1774 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 387ms/epoch - 19ms/step
#   → LSTM cells: 4
# Epoch 1/200
# 20/20 - 6s - loss: 0.5436 - accuracy: 0.7469 - f1_score: 0.6663 - val_loss: 0.3078 - val_accuracy: 0.9000 - val_f1_score: 0.8910 - 6s/epoch - 294ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2594 - accuracy: 0.9156 - f1_score: 0.9072 - val_loss: 0.1983 - val_accuracy: 0.9125 - val_f1_score: 0.8992 - 488ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1658 - accuracy: 0.9500 - f1_score: 0.9472 - val_loss: 0.2581 - val_accuracy: 0.9250 - val_f1_score: 0.9162 - 462ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1287 - accuracy: 0.9625 - f1_score: 0.9610 - val_loss: 0.2105 - val_accuracy: 0.9125 - val_f1_score: 0.9037 - 430ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0920 - accuracy: 0.9656 - f1_score: 0.9655 - val_loss: 0.2456 - val_accuracy: 0.9000 - val_f1_score: 0.8904 - 447ms/epoch - 22ms/step
#   → LSTM cells: 5
# Epoch 1/200
# 20/20 - 6s - loss: 0.5552 - accuracy: 0.7719 - f1_score: 0.7191 - val_loss: 0.3668 - val_accuracy: 0.8500 - val_f1_score: 0.8302 - 6s/epoch - 316ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.3021 - accuracy: 0.8938 - f1_score: 0.8882 - val_loss: 0.2809 - val_accuracy: 0.9250 - val_f1_score: 0.9146 - 503ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2465 - accuracy: 0.9156 - f1_score: 0.9120 - val_loss: 0.2471 - val_accuracy: 0.9000 - val_f1_score: 0.8862 - 499ms/epoch - 25ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1771 - accuracy: 0.9438 - f1_score: 0.9417 - val_loss: 0.2814 - val_accuracy: 0.9000 - val_f1_score: 0.8885 - 420ms/epoch - 21ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1311 - accuracy: 0.9656 - f1_score: 0.9638 - val_loss: 0.2634 - val_accuracy: 0.9375 - val_f1_score: 0.9269 - 374ms/epoch - 19ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1141 - accuracy: 0.9656 - f1_score: 0.9649 - val_loss: 0.3142 - val_accuracy: 0.9375 - val_f1_score: 0.9295 - 379ms/epoch - 19ms/step
#   → LSTM cells: 6
# Epoch 1/200
# 20/20 - 6s - loss: 0.5513 - accuracy: 0.7500 - f1_score: 0.7026 - val_loss: 0.3154 - val_accuracy: 0.8875 - val_f1_score: 0.8773 - 6s/epoch - 302ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2849 - accuracy: 0.9062 - f1_score: 0.9032 - val_loss: 0.1873 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 509ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2076 - accuracy: 0.9187 - f1_score: 0.9152 - val_loss: 0.1880 - val_accuracy: 0.9375 - val_f1_score: 0.9283 - 487ms/epoch - 24ms/step
# Epoch 4/200
# 20/20 - 1s - loss: 0.1325 - accuracy: 0.9656 - f1_score: 0.9638 - val_loss: 0.1425 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 532ms/epoch - 27ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0990 - accuracy: 0.9750 - f1_score: 0.9726 - val_loss: 0.1830 - val_accuracy: 0.9375 - val_f1_score: 0.9283 - 476ms/epoch - 24ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0580 - accuracy: 0.9844 - f1_score: 0.9837 - val_loss: 0.2271 - val_accuracy: 0.9375 - val_f1_score: 0.9283 - 388ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0376 - accuracy: 0.9875 - f1_score: 0.9870 - val_loss: 0.2237 - val_accuracy: 0.9375 - val_f1_score: 0.9283 - 399ms/epoch - 20ms/step
#   → LSTM cells: 7
# Epoch 1/200
# 20/20 - 6s - loss: 0.5103 - accuracy: 0.7937 - f1_score: 0.7821 - val_loss: 0.2619 - val_accuracy: 0.9000 - val_f1_score: 0.8908 - 6s/epoch - 287ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2953 - accuracy: 0.9031 - f1_score: 0.8943 - val_loss: 0.2536 - val_accuracy: 0.9125 - val_f1_score: 0.8991 - 511ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1956 - accuracy: 0.9406 - f1_score: 0.9356 - val_loss: 0.2168 - val_accuracy: 0.9375 - val_f1_score: 0.9278 - 466ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1694 - accuracy: 0.9438 - f1_score: 0.9400 - val_loss: 0.2008 - val_accuracy: 0.9375 - val_f1_score: 0.9278 - 379ms/epoch - 19ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1507 - accuracy: 0.9500 - f1_score: 0.9475 - val_loss: 0.2768 - val_accuracy: 0.8875 - val_f1_score: 0.8691 - 376ms/epoch - 19ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0939 - accuracy: 0.9719 - f1_score: 0.9694 - val_loss: 0.1216 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 373ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0510 - accuracy: 0.9906 - f1_score: 0.9898 - val_loss: 0.1370 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 391ms/epoch - 20ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0293 - accuracy: 0.9937 - f1_score: 0.9936 - val_loss: 0.1674 - val_accuracy: 0.9375 - val_f1_score: 0.9270 - 375ms/epoch - 19ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0376 - accuracy: 0.9875 - f1_score: 0.9860 - val_loss: 0.1745 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 388ms/epoch - 19ms/step
#   → LSTM cells: 8
# Epoch 1/200
# 20/20 - 6s - loss: 0.4841 - accuracy: 0.7750 - f1_score: 0.7610 - val_loss: 0.1982 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 6s/epoch - 315ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2360 - accuracy: 0.9281 - f1_score: 0.9246 - val_loss: 0.3149 - val_accuracy: 0.8500 - val_f1_score: 0.8318 - 506ms/epoch - 25ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1816 - accuracy: 0.9438 - f1_score: 0.9371 - val_loss: 0.1572 - val_accuracy: 0.9500 - val_f1_score: 0.9462 - 485ms/epoch - 24ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1498 - accuracy: 0.9531 - f1_score: 0.9499 - val_loss: 0.1478 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 391ms/epoch - 20ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1171 - accuracy: 0.9563 - f1_score: 0.9525 - val_loss: 0.1448 - val_accuracy: 0.9375 - val_f1_score: 0.9332 - 387ms/epoch - 19ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0815 - accuracy: 0.9750 - f1_score: 0.9737 - val_loss: 0.1863 - val_accuracy: 0.9500 - val_f1_score: 0.9413 - 374ms/epoch - 19ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0497 - accuracy: 0.9875 - f1_score: 0.9860 - val_loss: 0.1860 - val_accuracy: 0.9500 - val_f1_score: 0.9413 - 393ms/epoch - 20ms/step
#   → LSTM cells: 9
# Epoch 1/200
# 20/20 - 6s - loss: 0.5063 - accuracy: 0.8219 - f1_score: 0.8037 - val_loss: 0.2407 - val_accuracy: 0.9250 - val_f1_score: 0.9158 - 6s/epoch - 297ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2428 - accuracy: 0.9250 - f1_score: 0.9192 - val_loss: 0.2214 - val_accuracy: 0.9375 - val_f1_score: 0.9282 - 539ms/epoch - 27ms/step
# Epoch 3/200
# 20/20 - 1s - loss: 0.1880 - accuracy: 0.9438 - f1_score: 0.9391 - val_loss: 0.2282 - val_accuracy: 0.9250 - val_f1_score: 0.9122 - 506ms/epoch - 25ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1885 - accuracy: 0.9375 - f1_score: 0.9285 - val_loss: 0.1812 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 430ms/epoch - 21ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1140 - accuracy: 0.9625 - f1_score: 0.9581 - val_loss: 0.3649 - val_accuracy: 0.8500 - val_f1_score: 0.8310 - 381ms/epoch - 19ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1508 - accuracy: 0.9438 - f1_score: 0.9395 - val_loss: 0.2407 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 408ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0807 - accuracy: 0.9781 - f1_score: 0.9772 - val_loss: 0.1777 - val_accuracy: 0.9375 - val_f1_score: 0.9282 - 406ms/epoch - 20ms/step
# Processing CNN Model: resnet50.h5
#   → LSTM cells: 1
# Epoch 1/200
# 20/20 - 8s - loss: 0.6903 - accuracy: 0.5531 - f1_score: 0.4368 - val_loss: 0.6647 - val_accuracy: 0.8750 - val_f1_score: 0.8663 - 8s/epoch - 400ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.5844 - accuracy: 0.8719 - f1_score: 0.8554 - val_loss: 0.4345 - val_accuracy: 0.9375 - val_f1_score: 0.9322 - 561ms/epoch - 28ms/step
# Epoch 3/200
# 20/20 - 1s - loss: 0.3362 - accuracy: 0.9187 - f1_score: 0.9153 - val_loss: 0.2081 - val_accuracy: 0.9375 - val_f1_score: 0.9282 - 545ms/epoch - 27ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.2119 - accuracy: 0.9344 - f1_score: 0.9314 - val_loss: 0.1381 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 494ms/epoch - 25ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1531 - accuracy: 0.9563 - f1_score: 0.9549 - val_loss: 0.1365 - val_accuracy: 0.9375 - val_f1_score: 0.9196 - 398ms/epoch - 20ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1375 - accuracy: 0.9625 - f1_score: 0.9612 - val_loss: 0.1282 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 399ms/epoch - 20ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1276 - accuracy: 0.9688 - f1_score: 0.9675 - val_loss: 0.1234 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 444ms/epoch - 22ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.1067 - accuracy: 0.9781 - f1_score: 0.9776 - val_loss: 0.1394 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 394ms/epoch - 20ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.1039 - accuracy: 0.9781 - f1_score: 0.9769 - val_loss: 0.1382 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 407ms/epoch - 20ms/step
#   → LSTM cells: 2
# Epoch 1/200
# 20/20 - 7s - loss: 0.4949 - accuracy: 0.8531 - f1_score: 0.8455 - val_loss: 0.2485 - val_accuracy: 0.9000 - val_f1_score: 0.8898 - 7s/epoch - 334ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2375 - accuracy: 0.9219 - f1_score: 0.9188 - val_loss: 0.1803 - val_accuracy: 0.9375 - val_f1_score: 0.9270 - 522ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1753 - accuracy: 0.9469 - f1_score: 0.9439 - val_loss: 0.1548 - val_accuracy: 0.9625 - val_f1_score: 0.9577 - 447ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1758 - accuracy: 0.9438 - f1_score: 0.9407 - val_loss: 0.2230 - val_accuracy: 0.9125 - val_f1_score: 0.9033 - 442ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1514 - accuracy: 0.9594 - f1_score: 0.9561 - val_loss: 0.1442 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 437ms/epoch - 22ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1071 - accuracy: 0.9719 - f1_score: 0.9701 - val_loss: 0.1558 - val_accuracy: 0.9375 - val_f1_score: 0.9287 - 441ms/epoch - 22ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0681 - accuracy: 0.9875 - f1_score: 0.9859 - val_loss: 0.1721 - val_accuracy: 0.9375 - val_f1_score: 0.9272 - 425ms/epoch - 21ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0907 - accuracy: 0.9812 - f1_score: 0.9808 - val_loss: 0.2067 - val_accuracy: 0.9500 - val_f1_score: 0.9448 - 430ms/epoch - 21ms/step
#   → LSTM cells: 3
# Epoch 1/200
# 20/20 - 6s - loss: 0.6198 - accuracy: 0.6781 - f1_score: 0.5711 - val_loss: 0.5251 - val_accuracy: 0.7250 - val_f1_score: 0.6964 - 6s/epoch - 300ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.4020 - accuracy: 0.8625 - f1_score: 0.8474 - val_loss: 0.2076 - val_accuracy: 0.9375 - val_f1_score: 0.9270 - 484ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2670 - accuracy: 0.9156 - f1_score: 0.9109 - val_loss: 0.2487 - val_accuracy: 0.9250 - val_f1_score: 0.9171 - 451ms/epoch - 23ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.2227 - accuracy: 0.9312 - f1_score: 0.9291 - val_loss: 0.1670 - val_accuracy: 0.9375 - val_f1_score: 0.9320 - 448ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1882 - accuracy: 0.9375 - f1_score: 0.9327 - val_loss: 0.1448 - val_accuracy: 0.9250 - val_f1_score: 0.9145 - 446ms/epoch - 22ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1370 - accuracy: 0.9719 - f1_score: 0.9708 - val_loss: 0.1400 - val_accuracy: 0.9375 - val_f1_score: 0.9282 - 448ms/epoch - 22ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1433 - accuracy: 0.9563 - f1_score: 0.9551 - val_loss: 0.1166 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 448ms/epoch - 22ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.1149 - accuracy: 0.9781 - f1_score: 0.9770 - val_loss: 0.1144 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 447ms/epoch - 22ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0914 - accuracy: 0.9812 - f1_score: 0.9790 - val_loss: 0.1217 - val_accuracy: 0.9750 - val_f1_score: 0.9667 - 442ms/epoch - 22ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0837 - accuracy: 0.9812 - f1_score: 0.9771 - val_loss: 0.1177 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 454ms/epoch - 23ms/step
#   → LSTM cells: 4
# Epoch 1/200
# 20/20 - 6s - loss: 0.6110 - accuracy: 0.7000 - f1_score: 0.6400 - val_loss: 0.4154 - val_accuracy: 0.9375 - val_f1_score: 0.9270 - 6s/epoch - 325ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2949 - accuracy: 0.9125 - f1_score: 0.9027 - val_loss: 0.2431 - val_accuracy: 0.9375 - val_f1_score: 0.9286 - 515ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1841 - accuracy: 0.9406 - f1_score: 0.9386 - val_loss: 0.1335 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 435ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1601 - accuracy: 0.9500 - f1_score: 0.9466 - val_loss: 0.1596 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 429ms/epoch - 21ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1047 - accuracy: 0.9750 - f1_score: 0.9729 - val_loss: 0.1010 - val_accuracy: 0.9750 - val_f1_score: 0.9667 - 443ms/epoch - 22ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0753 - accuracy: 0.9812 - f1_score: 0.9804 - val_loss: 0.1409 - val_accuracy: 0.9500 - val_f1_score: 0.9326 - 435ms/epoch - 22ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.0678 - accuracy: 0.9812 - f1_score: 0.9808 - val_loss: 0.1226 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 432ms/epoch - 22ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0471 - accuracy: 0.9906 - f1_score: 0.9904 - val_loss: 0.1298 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 442ms/epoch - 22ms/step
#   → LSTM cells: 5
# Epoch 1/200
# 20/20 - 6s - loss: 0.6564 - accuracy: 0.6313 - f1_score: 0.4920 - val_loss: 0.4947 - val_accuracy: 0.9250 - val_f1_score: 0.9199 - 6s/epoch - 302ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.4612 - accuracy: 0.8781 - f1_score: 0.8728 - val_loss: 0.3069 - val_accuracy: 0.9500 - val_f1_score: 0.9452 - 533ms/epoch - 27ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.3343 - accuracy: 0.9250 - f1_score: 0.9192 - val_loss: 0.2374 - val_accuracy: 0.9500 - val_f1_score: 0.9452 - 446ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.2449 - accuracy: 0.9281 - f1_score: 0.9256 - val_loss: 0.2299 - val_accuracy: 0.9500 - val_f1_score: 0.9448 - 449ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.2002 - accuracy: 0.9344 - f1_score: 0.9313 - val_loss: 0.1556 - val_accuracy: 0.9500 - val_f1_score: 0.9462 - 443ms/epoch - 22ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1502 - accuracy: 0.9500 - f1_score: 0.9473 - val_loss: 0.2135 - val_accuracy: 0.9250 - val_f1_score: 0.9170 - 438ms/epoch - 22ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1752 - accuracy: 0.9375 - f1_score: 0.9350 - val_loss: 0.1454 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 436ms/epoch - 22ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.1011 - accuracy: 0.9719 - f1_score: 0.9707 - val_loss: 0.1309 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 440ms/epoch - 22ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.0869 - accuracy: 0.9750 - f1_score: 0.9741 - val_loss: 0.1515 - val_accuracy: 0.9375 - val_f1_score: 0.9295 - 430ms/epoch - 21ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.0932 - accuracy: 0.9719 - f1_score: 0.9643 - val_loss: 0.1157 - val_accuracy: 0.9625 - val_f1_score: 0.9541 - 430ms/epoch - 22ms/step
# Epoch 11/200
# 20/20 - 0s - loss: 0.0717 - accuracy: 0.9812 - f1_score: 0.9795 - val_loss: 0.1403 - val_accuracy: 0.9625 - val_f1_score: 0.9586 - 416ms/epoch - 21ms/step
# Epoch 12/200
# 20/20 - 0s - loss: 0.0584 - accuracy: 0.9906 - f1_score: 0.9902 - val_loss: 0.1404 - val_accuracy: 0.9500 - val_f1_score: 0.9408 - 413ms/epoch - 21ms/step
# Epoch 13/200
# 20/20 - 0s - loss: 0.0490 - accuracy: 0.9937 - f1_score: 0.9930 - val_loss: 0.1499 - val_accuracy: 0.9250 - val_f1_score: 0.9148 - 426ms/epoch - 21ms/step
#   → LSTM cells: 6
# Epoch 1/200
# 20/20 - 6s - loss: 0.5363 - accuracy: 0.7688 - f1_score: 0.7434 - val_loss: 0.2509 - val_accuracy: 0.9250 - val_f1_score: 0.9158 - 6s/epoch - 322ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.2620 - accuracy: 0.9125 - f1_score: 0.9052 - val_loss: 0.1673 - val_accuracy: 0.9375 - val_f1_score: 0.9286 - 477ms/epoch - 24ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2016 - accuracy: 0.9406 - f1_score: 0.9372 - val_loss: 0.1822 - val_accuracy: 0.9125 - val_f1_score: 0.9030 - 435ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1531 - accuracy: 0.9594 - f1_score: 0.9556 - val_loss: 0.1336 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 434ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1234 - accuracy: 0.9656 - f1_score: 0.9644 - val_loss: 0.1105 - val_accuracy: 0.9750 - val_f1_score: 0.9667 - 435ms/epoch - 22ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1115 - accuracy: 0.9719 - f1_score: 0.9709 - val_loss: 0.1093 - val_accuracy: 0.9875 - val_f1_score: 0.9845 - 432ms/epoch - 22ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1061 - accuracy: 0.9688 - f1_score: 0.9655 - val_loss: 0.1446 - val_accuracy: 0.9500 - val_f1_score: 0.9461 - 434ms/epoch - 22ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.0925 - accuracy: 0.9688 - f1_score: 0.9649 - val_loss: 0.1553 - val_accuracy: 0.9625 - val_f1_score: 0.9541 - 431ms/epoch - 22ms/step
#   → LSTM cells: 7
# Epoch 1/200
# 20/20 - 6s - loss: 0.4428 - accuracy: 0.8156 - f1_score: 0.7974 - val_loss: 0.2605 - val_accuracy: 0.9125 - val_f1_score: 0.9034 - 6s/epoch - 323ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2891 - accuracy: 0.9000 - f1_score: 0.8934 - val_loss: 0.1900 - val_accuracy: 0.9500 - val_f1_score: 0.9399 - 532ms/epoch - 27ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1929 - accuracy: 0.9438 - f1_score: 0.9418 - val_loss: 0.1444 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 450ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1412 - accuracy: 0.9531 - f1_score: 0.9504 - val_loss: 0.1286 - val_accuracy: 0.9500 - val_f1_score: 0.9399 - 452ms/epoch - 23ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1963 - accuracy: 0.9375 - f1_score: 0.9356 - val_loss: 0.3469 - val_accuracy: 0.8625 - val_f1_score: 0.8481 - 438ms/epoch - 22ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1710 - accuracy: 0.9281 - f1_score: 0.9244 - val_loss: 0.1289 - val_accuracy: 0.9625 - val_f1_score: 0.9541 - 431ms/epoch - 22ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1106 - accuracy: 0.9563 - f1_score: 0.9551 - val_loss: 0.1800 - val_accuracy: 0.9500 - val_f1_score: 0.9448 - 437ms/epoch - 22ms/step
#   → LSTM cells: 8
# Epoch 1/200
# 20/20 - 6s - loss: 0.5087 - accuracy: 0.8125 - f1_score: 0.7910 - val_loss: 0.2298 - val_accuracy: 0.9250 - val_f1_score: 0.9145 - 6s/epoch - 304ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2676 - accuracy: 0.9094 - f1_score: 0.9072 - val_loss: 0.1710 - val_accuracy: 0.9250 - val_f1_score: 0.9153 - 521ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.2074 - accuracy: 0.9250 - f1_score: 0.9154 - val_loss: 0.1352 - val_accuracy: 0.9625 - val_f1_score: 0.9537 - 439ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1495 - accuracy: 0.9563 - f1_score: 0.9514 - val_loss: 0.1336 - val_accuracy: 0.9500 - val_f1_score: 0.9399 - 428ms/epoch - 21ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.1137 - accuracy: 0.9719 - f1_score: 0.9700 - val_loss: 0.1206 - val_accuracy: 0.9750 - val_f1_score: 0.9667 - 431ms/epoch - 22ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.1062 - accuracy: 0.9719 - f1_score: 0.9667 - val_loss: 0.1260 - val_accuracy: 0.9750 - val_f1_score: 0.9667 - 413ms/epoch - 21ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.1298 - accuracy: 0.9531 - f1_score: 0.9501 - val_loss: 0.2054 - val_accuracy: 0.9500 - val_f1_score: 0.9448 - 409ms/epoch - 20ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.1262 - accuracy: 0.9594 - f1_score: 0.9576 - val_loss: 0.1257 - val_accuracy: 0.9500 - val_f1_score: 0.9399 - 421ms/epoch - 21ms/step
#   → LSTM cells: 9
# Epoch 1/200
# 20/20 - 7s - loss: 0.5553 - accuracy: 0.7500 - f1_score: 0.7031 - val_loss: 0.2658 - val_accuracy: 0.9000 - val_f1_score: 0.8895 - 7s/epoch - 325ms/step
# Epoch 2/200
# 20/20 - 1s - loss: 0.2627 - accuracy: 0.8938 - f1_score: 0.8882 - val_loss: 0.2049 - val_accuracy: 0.9250 - val_f1_score: 0.9162 - 515ms/epoch - 26ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.1778 - accuracy: 0.9281 - f1_score: 0.9252 - val_loss: 0.1503 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 450ms/epoch - 22ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.1208 - accuracy: 0.9625 - f1_score: 0.9613 - val_loss: 0.1635 - val_accuracy: 0.9375 - val_f1_score: 0.9287 - 435ms/epoch - 22ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.0751 - accuracy: 0.9812 - f1_score: 0.9807 - val_loss: 0.1821 - val_accuracy: 0.9500 - val_f1_score: 0.9412 - 429ms/epoch - 21ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.0624 - accuracy: 0.9875 - f1_score: 0.9872 - val_loss: 0.1742 - val_accuracy: 0.9750 - val_f1_score: 0.9716 - 435ms/epoch - 22ms/step
